# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1320
# 1323
# 1323
# 1328
# 1328
# 1330
# 1331
# 1332
# 1333
# 1334
# 1343
# 1350
# 1351
# 1353
# 1354
# 1355
# 1359
# 1362
# 1363
# 1364
# 1366
# 1367
# 1371
# 1372
# 1374
# 1377
# 1380
# 1382
# 1383
# 1386
# 1387
# 1388
# 1392
# 1393
# 1394
# 1397
# 1398
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424

# %%
Started = True

with open( 'user_ids_headers.txt', 'r' ) as f:

    for line in f:

        # запись "if Started" эквивалентна "if Started == True"

        if Started:

            # эта строчка выполняется один раз только на первом шаге цикла

            Started = False

        else:

            # эту строчку выполняем со второго и во всех следующих шагах цикла

            print( line.strip() )
# Out:
# 1010
# 1036
# 1041
# 1041
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1047
# 1047
# 1052
# 1052
# 1057
# 1057
# 1062
# 1067
# 1078
# 1085
# 1096
# 1098
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1105
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1111
# 1112
# 1112
# 1113
# 1113
# 1114
# 1114
# 1116
# 1118
# 1118
# 1123
# 1123
# 1128
# 1134
# 1134
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1136
# 1136
# 1140
# 1140
# 1141
# 1145
# 1145
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1150
# 1154
# 1154
# 1159
# 1159
# 1164
# 1167
# 1175
# 1181
# 1182
# 1182
# 1193
# 1193
# 1198
# 1198
# 1201
# 1203
# 1203
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1208
# 1208
# 1209
# 1213
# 1213
# 1218
# 1218
# 1219
# 1223
# 1223
# 1224
# 1226
# 1226
# 1228
# 1228
# 1230
# 1233
# 1233
# 1236
# 1238
# 1238
# 1242
# 1243
# 1243
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1246
# 1248
# 1248
# 1252
# 1252
# 1253
# 1253
# 1258
# 1258
# 1263
# 1263
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1267
# 1268
# 1268
# 1269
# 1270
# 1273
# 1273
# 1274
# 1278
# 1278
# 1279
# 1281
# 1283
# 1283
# 1288
# 1288
# 1291
# 1293
# 1293
# 1294
# 1296
# 1298
# 1298
# 1298
# 1300
# 1300
# 1302
# 1303
# 1303
# 1308
# 1308
# 1313
# 1313
# 1315
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1318
# 1320
# 1323
# 1323
# 1328
# 1328
# 1330
# 1331
# 1332
# 1333
# 1334
# 1343
# 1350
# 1351
# 1353
# 1354
# 1355
# 1359
# 1362
# 1363
# 1364
# 1366
# 1367
# 1371
# 1372
# 1374
# 1377
# 1380
# 1382
# 1383
# 1386
# 1387
# 1388
# 1392
# 1393
# 1394
# 1397
# 1398
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424
# 1424

# %%
with open( 'data_3_columns.txt', 'r' ) as f:

    for line in f:

        print( line.strip() )
# Out:
# seo	google	20,20
# sem	yandex	15,60
# email	promo	13,20
# sem	yandex	9,80
# sem	google	14,80
# sem	google	14,40
# sem	google	14,00
# brand	yandex	20,00
# sem	yandex	16,20
# email	promo	11,00
# cpa-partners	burgerclub	10,80
# seo	google	22,60
# seo	google	22,40
# sem	yandex	24,40
# seo	google	16,60
# sem	yandex	8,60
# seo	yandex	12,40
# cpa-partners	food-delivery	16,20
# email	promo	24,00
# sem	yandex	18,80
# email	promo	11,80
# sem	google	9,40
# sem	google	11,20
# email	promo	19,00
# sem	google	23,40
# cpc-partners	city-magazine	17,00
# seo	google	20,80
# email	promo	15,60
# cpc-partners	foody	22,40
# seo	yandex	15,60
# cpa-partners	food-delivery	21,00
# seo	google	22,40
# sem	google	20,40
# email	promo	26,00
# seo	yandex	18,40
# email	promo	14,60
# seo	yandex	29,80
# email	promo	20,00
# sem	google	19,00
# brand	google	16,40
# sem	yandex	16,20
# sem	yandex	17,80
# email	promo	18,80
# cpa-partners	burgerclub	20,00
# seo	google	21,00
# seo	yandex	16,60
# email	promo	20,00
# sem	yandex	19,80
# email	promo	16,80
# cpa-partners	food-delivery	24,00
# sem	yandex	12,00
# sem	yandex	10,20
# email	promo	24,00
# sem	yandex	15,80
# sem	yandex	22,00
# sem	google	17,40
# sem	yandex	14,80
# email	promo	20,00
# brand	yandex	11,60
# seo	yandex	20,00
# sem	yandex	16,00
# seo	yandex	11,20
# seo	google	12,20
# sem	yandex	19,20
# sem	google	17,80
# sem	google	19,80
# email	promo	8,60
# email	promo	28,60
# email	newsletter	18,80
# sem	google	17,60
# email	promo	16,00
# cpa-partners	food-delivery	15,40
# sem	yandex	21,60
# email	promo	7,60
# brand	yandex	21,60
# smm	facebook	17,40
# sem	google	22,00
# email	promo	22,00
# email	promo	16,00
# seo	yandex	16,00
# sem	yandex	20,00
# email	promo	10,00
# sem	yandex	21,20
# seo	yandex	30,40
# cpa-partners	burgerclub	18,80
# sem	yandex	14,00
# email	promo	22,00
# sem	google	16,00
# sem	yandex	12,60
# sem	google	13,40
# seo	yandex	13,60
# sem	yandex	10,20
# brand	yandex	17,40
# sem	google	22,40
# sem	yandex	11,40
# sem	google	14,00
# seo	yandex	22,40
# sem	yandex	18,00
# brand	direct	17,00
# cpa-partners	food-delivery	24,80
# brand	google	16,60
# sem	google	17,80
# sem	google	9,00
# email	promo	10,60
# brand	google	23,40
# cpa-partners	burgerclub	21,00
# email	promo	16,60
# cpc-partners	foody	24,20
# seo	google	20,40
# seo	yandex	25,60
# brand	yandex	19,80
# smm	facebook	16,40
# email	promo	16,20
# seo	yandex	17,00
# email	promo	16,80
# sem	yandex	19,80
# seo	yandex	15,60
# email	newsletter	19,20
# sem	google	23,20
# sem	yandex	10,80
# sem	google	24,40
# sem	yandex	13,40
# seo	yandex	12,00
# smm	facebook	18,60
# sem	google	16,60
# cpa-partners	burgerclub	12,20
# cpa-partners	burgerclub	22,40
# seo	google	15,40
# cpc-partners	city-magazine	17,20
# cpa-partners	burgerclub	17,60
# email	promo	16,40
# email	promo	18,60
# email	promo	19,80
# brand	google	18,80
# seo	google	17,60
# email	promo	20,60
# cpa-partners	food-delivery	15,00
# sem	yandex	22,00
# email	promo	17,40
# seo	yandex	13,60
# seo	yandex	17,60
# email	promo	18,40
# email	promo	20,40
# sem	yandex	20,00
# brand	yandex	17,80
# seo	google	16,00
# email	promo	14,60
# email	promo	17,20
# sem	yandex	13,60
# email	promo	23,60
# sem	google	15,60
# sem	yandex	21,40
# sem	google	13,00
# seo	yandex	18,60
# cpa-partners	burgerclub	20,60
# seo	yandex	11,40
# email	promo	18,00
# smm	vk	12,00
# sem	yandex	16,00
# sem	google	12,20
# brand	direct	23,00
# sem	yandex	24,00
# email	promo	11,80
# email	newsletter	17,20
# email	newsletter	24,60
# sem	yandex	30,40
# sem	yandex	18,00
# email	promo	15,00
# sem	google	13,20
# seo	yandex	28,80
# sem	yandex	22,00
# email	promo	15,60
# sem	yandex	13,60
# sem	google	8,60
# sem	google	22,00
# email	promo	20,00
# sem	yandex	12,60
# sem	google	18,00
# brand	direct	11,00
# email	promo	12,20
# sem	yandex	18,00
# email	promo	12,40
# seo	google	13,00
# brand	direct	21,40
# sem	yandex	13,60
# cpa-partners	food-delivery	17,40
# sem	google	15,00
# seo	yandex	14,40
# brand	direct	16,00
# seo	yandex	12,00
# sem	yandex	12,80
# email	promo	21,40
# sem	yandex	17,40
# sem	yandex	21,60
# email	promo	16,00
# sem	google	16,40
# sem	yandex	16,00
# email	promo	22,00
# brand	yandex	21,80
# email	promo	14,60
# seo	yandex	22,00
# email	promo	25,00
# sem	google	15,60
# email	promo	17,80
# sem	yandex	14,80
# sem	yandex	18,20
# sem	google	12,60
# email	promo	11,80
# sem	yandex	16,00
# seo	yandex	30,40
# seo	google	13,40
# email	newsletter	18,40
# email	promo	20,00
# smm	vk	17,00
# sem	google	26,00
# sem	google	21,00
# cpc-partners	foody	19,40
# sem	yandex	16,00
# sem	yandex	12,80
# sem	google	14,00
# cpa-partners	burgerclub	21,80
# cpc-partners	city-magazine	11,80
# sem	google	25,80
# sem	google	18,00
# sem	google	10,20
# email	promo	12,00
# sem	google	13,80
# sem	google	16,60
# sem	google	11,40
# brand	google	13,40
# sem	yandex	14,00
# sem	google	16,60
# email	promo	24,00
# email	promo	10,20
# email	promo	18,60
# sem	yandex	21,60
# cpa-partners	burgerclub	20,20
# sem	yandex	18,00
# email	promo	17,40
# email	promo	22,00
# sem	yandex	17,40
# sem	yandex	19,00
# smm	facebook	18,00
# brand	google	16,00
# email	promo	28,60
# sem	yandex	18,40
# email	promo	18,80
# seo	yandex	17,80
# sem	yandex	16,80
# sem	yandex	19,40
# sem	google	20,00
# sem	yandex	16,00
# sem	google	22,00
# cpa-partners	food-delivery	12,80
# email	promo	20,00
# sem	yandex	17,40
# email	promo	15,60
# sem	google	22,00
# sem	google	14,40
# sem	google	12,20
# seo	yandex	12,20
# email	promo	20,00
# cpa-partners	food-delivery	13,00
# sem	yandex	22,40
# sem	yandex	13,60
# sem	google	30,40
# sem	yandex	12,40
# sem	yandex	16,00
# seo	yandex	30,40
# cpc-partners	city-magazine	23,20
# sem	google	20,00
# email	promo	12,60
# sem	google	14,60
# cpc-partners	city-magazine	11,80
# smm	facebook	20,20
# sem	google	10,00
# email	promo	12,80
# sem	yandex	20,60
# seo	yandex	18,00
# cpa-partners	food-delivery	13,80
# seo	yandex	12,80
# sem	yandex	17,20
# sem	google	16,00
# email	promo	14,20
# sem	yandex	19,60
# seo	google	22,40
# email	promo	14,80
# sem	google	13,00
# sem	google	13,60
# email	promo	12,60
# seo	yandex	19,20
# email	promo	20,20
# sem	google	16,00
# sem	yandex	11,60

# %%
with open( 'data_3_columns.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        print( line )
# Out:
# ['seo', 'google', '20,20']
# ['sem', 'yandex', '15,60']
# ['email', 'promo', '13,20']
# ['sem', 'yandex', '9,80']
# ['sem', 'google', '14,80']
# ['sem', 'google', '14,40']
# ['sem', 'google', '14,00']
# ['brand', 'yandex', '20,00']
# ['sem', 'yandex', '16,20']
# ['email', 'promo', '11,00']
# ['cpa-partners', 'burgerclub', '10,80']
# ['seo', 'google', '22,60']
# ['seo', 'google', '22,40']
# ['sem', 'yandex', '24,40']
# ['seo', 'google', '16,60']
# ['sem', 'yandex', '8,60']
# ['seo', 'yandex', '12,40']
# ['cpa-partners', 'food-delivery', '16,20']
# ['email', 'promo', '24,00']
# ['sem', 'yandex', '18,80']
# ['email', 'promo', '11,80']
# ['sem', 'google', '9,40']
# ['sem', 'google', '11,20']
# ['email', 'promo', '19,00']
# ['sem', 'google', '23,40']
# ['cpc-partners', 'city-magazine', '17,00']
# ['seo', 'google', '20,80']
# ['email', 'promo', '15,60']
# ['cpc-partners', 'foody', '22,40']
# ['seo', 'yandex', '15,60']
# ['cpa-partners', 'food-delivery', '21,00']
# ['seo', 'google', '22,40']
# ['sem', 'google', '20,40']
# ['email', 'promo', '26,00']
# ['seo', 'yandex', '18,40']
# ['email', 'promo', '14,60']
# ['seo', 'yandex', '29,80']
# ['email', 'promo', '20,00']
# ['sem', 'google', '19,00']
# ['brand', 'google', '16,40']
# ['sem', 'yandex', '16,20']
# ['sem', 'yandex', '17,80']
# ['email', 'promo', '18,80']
# ['cpa-partners', 'burgerclub', '20,00']
# ['seo', 'google', '21,00']
# ['seo', 'yandex', '16,60']
# ['email', 'promo', '20,00']
# ['sem', 'yandex', '19,80']
# ['email', 'promo', '16,80']
# ['cpa-partners', 'food-delivery', '24,00']
# ['sem', 'yandex', '12,00']
# ['sem', 'yandex', '10,20']
# ['email', 'promo', '24,00']
# ['sem', 'yandex', '15,80']
# ['sem', 'yandex', '22,00']
# ['sem', 'google', '17,40']
# ['sem', 'yandex', '14,80']
# ['email', 'promo', '20,00']
# ['brand', 'yandex', '11,60']
# ['seo', 'yandex', '20,00']
# ['sem', 'yandex', '16,00']
# ['seo', 'yandex', '11,20']
# ['seo', 'google', '12,20']
# ['sem', 'yandex', '19,20']
# ['sem', 'google', '17,80']
# ['sem', 'google', '19,80']
# ['email', 'promo', '8,60']
# ['email', 'promo', '28,60']
# ['email', 'newsletter', '18,80']
# ['sem', 'google', '17,60']
# ['email', 'promo', '16,00']
# ['cpa-partners', 'food-delivery', '15,40']
# ['sem', 'yandex', '21,60']
# ['email', 'promo', '7,60']
# ['brand', 'yandex', '21,60']
# ['smm', 'facebook', '17,40']
# ['sem', 'google', '22,00']
# ['email', 'promo', '22,00']
# ['email', 'promo', '16,00']
# ['seo', 'yandex', '16,00']
# ['sem', 'yandex', '20,00']
# ['email', 'promo', '10,00']
# ['sem', 'yandex', '21,20']
# ['seo', 'yandex', '30,40']
# ['cpa-partners', 'burgerclub', '18,80']
# ['sem', 'yandex', '14,00']
# ['email', 'promo', '22,00']
# ['sem', 'google', '16,00']
# ['sem', 'yandex', '12,60']
# ['sem', 'google', '13,40']
# ['seo', 'yandex', '13,60']
# ['sem', 'yandex', '10,20']
# ['brand', 'yandex', '17,40']
# ['sem', 'google', '22,40']
# ['sem', 'yandex', '11,40']
# ['sem', 'google', '14,00']
# ['seo', 'yandex', '22,40']
# ['sem', 'yandex', '18,00']
# ['brand', 'direct', '17,00']
# ['cpa-partners', 'food-delivery', '24,80']
# ['brand', 'google', '16,60']
# ['sem', 'google', '17,80']
# ['sem', 'google', '9,00']
# ['email', 'promo', '10,60']
# ['brand', 'google', '23,40']
# ['cpa-partners', 'burgerclub', '21,00']
# ['email', 'promo', '16,60']
# ['cpc-partners', 'foody', '24,20']
# ['seo', 'google', '20,40']
# ['seo', 'yandex', '25,60']
# ['brand', 'yandex', '19,80']
# ['smm', 'facebook', '16,40']
# ['email', 'promo', '16,20']
# ['seo', 'yandex', '17,00']
# ['email', 'promo', '16,80']
# ['sem', 'yandex', '19,80']
# ['seo', 'yandex', '15,60']
# ['email', 'newsletter', '19,20']
# ['sem', 'google', '23,20']
# ['sem', 'yandex', '10,80']
# ['sem', 'google', '24,40']
# ['sem', 'yandex', '13,40']
# ['seo', 'yandex', '12,00']
# ['smm', 'facebook', '18,60']
# ['sem', 'google', '16,60']
# ['cpa-partners', 'burgerclub', '12,20']
# ['cpa-partners', 'burgerclub', '22,40']
# ['seo', 'google', '15,40']
# ['cpc-partners', 'city-magazine', '17,20']
# ['cpa-partners', 'burgerclub', '17,60']
# ['email', 'promo', '16,40']
# ['email', 'promo', '18,60']
# ['email', 'promo', '19,80']
# ['brand', 'google', '18,80']
# ['seo', 'google', '17,60']
# ['email', 'promo', '20,60']
# ['cpa-partners', 'food-delivery', '15,00']
# ['sem', 'yandex', '22,00']
# ['email', 'promo', '17,40']
# ['seo', 'yandex', '13,60']
# ['seo', 'yandex', '17,60']
# ['email', 'promo', '18,40']
# ['email', 'promo', '20,40']
# ['sem', 'yandex', '20,00']
# ['brand', 'yandex', '17,80']
# ['seo', 'google', '16,00']
# ['email', 'promo', '14,60']
# ['email', 'promo', '17,20']
# ['sem', 'yandex', '13,60']
# ['email', 'promo', '23,60']
# ['sem', 'google', '15,60']
# ['sem', 'yandex', '21,40']
# ['sem', 'google', '13,00']
# ['seo', 'yandex', '18,60']
# ['cpa-partners', 'burgerclub', '20,60']
# ['seo', 'yandex', '11,40']
# ['email', 'promo', '18,00']
# ['smm', 'vk', '12,00']
# ['sem', 'yandex', '16,00']
# ['sem', 'google', '12,20']
# ['brand', 'direct', '23,00']
# ['sem', 'yandex', '24,00']
# ['email', 'promo', '11,80']
# ['email', 'newsletter', '17,20']
# ['email', 'newsletter', '24,60']
# ['sem', 'yandex', '30,40']
# ['sem', 'yandex', '18,00']
# ['email', 'promo', '15,00']
# ['sem', 'google', '13,20']
# ['seo', 'yandex', '28,80']
# ['sem', 'yandex', '22,00']
# ['email', 'promo', '15,60']
# ['sem', 'yandex', '13,60']
# ['sem', 'google', '8,60']
# ['sem', 'google', '22,00']
# ['email', 'promo', '20,00']
# ['sem', 'yandex', '12,60']
# ['sem', 'google', '18,00']
# ['brand', 'direct', '11,00']
# ['email', 'promo', '12,20']
# ['sem', 'yandex', '18,00']
# ['email', 'promo', '12,40']
# ['seo', 'google', '13,00']
# ['brand', 'direct', '21,40']
# ['sem', 'yandex', '13,60']
# ['cpa-partners', 'food-delivery', '17,40']
# ['sem', 'google', '15,00']
# ['seo', 'yandex', '14,40']
# ['brand', 'direct', '16,00']
# ['seo', 'yandex', '12,00']
# ['sem', 'yandex', '12,80']
# ['email', 'promo', '21,40']
# ['sem', 'yandex', '17,40']
# ['sem', 'yandex', '21,60']
# ['email', 'promo', '16,00']
# ['sem', 'google', '16,40']
# ['sem', 'yandex', '16,00']
# ['email', 'promo', '22,00']
# ['brand', 'yandex', '21,80']
# ['email', 'promo', '14,60']
# ['seo', 'yandex', '22,00']
# ['email', 'promo', '25,00']
# ['sem', 'google', '15,60']
# ['email', 'promo', '17,80']
# ['sem', 'yandex', '14,80']
# ['sem', 'yandex', '18,20']
# ['sem', 'google', '12,60']
# ['email', 'promo', '11,80']
# ['sem', 'yandex', '16,00']
# ['seo', 'yandex', '30,40']
# ['seo', 'google', '13,40']
# ['email', 'newsletter', '18,40']
# ['email', 'promo', '20,00']
# ['smm', 'vk', '17,00']
# ['sem', 'google', '26,00']
# ['sem', 'google', '21,00']
# ['cpc-partners', 'foody', '19,40']
# ['sem', 'yandex', '16,00']
# ['sem', 'yandex', '12,80']
# ['sem', 'google', '14,00']
# ['cpa-partners', 'burgerclub', '21,80']
# ['cpc-partners', 'city-magazine', '11,80']
# ['sem', 'google', '25,80']
# ['sem', 'google', '18,00']
# ['sem', 'google', '10,20']
# ['email', 'promo', '12,00']
# ['sem', 'google', '13,80']
# ['sem', 'google', '16,60']
# ['sem', 'google', '11,40']
# ['brand', 'google', '13,40']
# ['sem', 'yandex', '14,00']
# ['sem', 'google', '16,60']
# ['email', 'promo', '24,00']
# ['email', 'promo', '10,20']
# ['email', 'promo', '18,60']
# ['sem', 'yandex', '21,60']
# ['cpa-partners', 'burgerclub', '20,20']
# ['sem', 'yandex', '18,00']
# ['email', 'promo', '17,40']
# ['email', 'promo', '22,00']
# ['sem', 'yandex', '17,40']
# ['sem', 'yandex', '19,00']
# ['smm', 'facebook', '18,00']
# ['brand', 'google', '16,00']
# ['email', 'promo', '28,60']
# ['sem', 'yandex', '18,40']
# ['email', 'promo', '18,80']
# ['seo', 'yandex', '17,80']
# ['sem', 'yandex', '16,80']
# ['sem', 'yandex', '19,40']
# ['sem', 'google', '20,00']
# ['sem', 'yandex', '16,00']
# ['sem', 'google', '22,00']
# ['cpa-partners', 'food-delivery', '12,80']
# ['email', 'promo', '20,00']
# ['sem', 'yandex', '17,40']
# ['email', 'promo', '15,60']
# ['sem', 'google', '22,00']
# ['sem', 'google', '14,40']
# ['sem', 'google', '12,20']
# ['seo', 'yandex', '12,20']
# ['email', 'promo', '20,00']
# ['cpa-partners', 'food-delivery', '13,00']
# ['sem', 'yandex', '22,40']
# ['sem', 'yandex', '13,60']
# ['sem', 'google', '30,40']
# ['sem', 'yandex', '12,40']
# ['sem', 'yandex', '16,00']
# ['seo', 'yandex', '30,40']
# ['cpc-partners', 'city-magazine', '23,20']
# ['sem', 'google', '20,00']
# ['email', 'promo', '12,60']
# ['sem', 'google', '14,60']
# ['cpc-partners', 'city-magazine', '11,80']
# ['smm', 'facebook', '20,20']
# ['sem', 'google', '10,00']
# ['email', 'promo', '12,80']
# ['sem', 'yandex', '20,60']
# ['seo', 'yandex', '18,00']
# ['cpa-partners', 'food-delivery', '13,80']
# ['seo', 'yandex', '12,80']
# ['sem', 'yandex', '17,20']
# ['sem', 'google', '16,00']
# ['email', 'promo', '14,20']
# ['sem', 'yandex', '19,60']
# ['seo', 'google', '22,40']
# ['email', 'promo', '14,80']
# ['sem', 'google', '13,00']
# ['sem', 'google', '13,60']
# ['email', 'promo', '12,60']
# ['seo', 'yandex', '19,20']
# ['email', 'promo', '20,20']
# ['sem', 'google', '16,00']
# ['sem', 'yandex', '11,60']

# %%
with open( 'data_3_columns.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        medium = line[0]

        source = line[1]

        amount_paid = line[2].replace(',', '.')

        print( line )

        print( source, medium, amount_paid )
# Out:
# ['seo', 'google', '20,20']
# google seo 20.20
# ['sem', 'yandex', '15,60']
# yandex sem 15.60
# ['email', 'promo', '13,20']
# promo email 13.20
# ['sem', 'yandex', '9,80']
# yandex sem 9.80
# ['sem', 'google', '14,80']
# google sem 14.80
# ['sem', 'google', '14,40']
# google sem 14.40
# ['sem', 'google', '14,00']
# google sem 14.00
# ['brand', 'yandex', '20,00']
# yandex brand 20.00
# ['sem', 'yandex', '16,20']
# yandex sem 16.20
# ['email', 'promo', '11,00']
# promo email 11.00
# ['cpa-partners', 'burgerclub', '10,80']
# burgerclub cpa-partners 10.80
# ['seo', 'google', '22,60']
# google seo 22.60
# ['seo', 'google', '22,40']
# google seo 22.40
# ['sem', 'yandex', '24,40']
# yandex sem 24.40
# ['seo', 'google', '16,60']
# google seo 16.60
# ['sem', 'yandex', '8,60']
# yandex sem 8.60
# ['seo', 'yandex', '12,40']
# yandex seo 12.40
# ['cpa-partners', 'food-delivery', '16,20']
# food-delivery cpa-partners 16.20
# ['email', 'promo', '24,00']
# promo email 24.00
# ['sem', 'yandex', '18,80']
# yandex sem 18.80
# ['email', 'promo', '11,80']
# promo email 11.80
# ['sem', 'google', '9,40']
# google sem 9.40
# ['sem', 'google', '11,20']
# google sem 11.20
# ['email', 'promo', '19,00']
# promo email 19.00
# ['sem', 'google', '23,40']
# google sem 23.40
# ['cpc-partners', 'city-magazine', '17,00']
# city-magazine cpc-partners 17.00
# ['seo', 'google', '20,80']
# google seo 20.80
# ['email', 'promo', '15,60']
# promo email 15.60
# ['cpc-partners', 'foody', '22,40']
# foody cpc-partners 22.40
# ['seo', 'yandex', '15,60']
# yandex seo 15.60
# ['cpa-partners', 'food-delivery', '21,00']
# food-delivery cpa-partners 21.00
# ['seo', 'google', '22,40']
# google seo 22.40
# ['sem', 'google', '20,40']
# google sem 20.40
# ['email', 'promo', '26,00']
# promo email 26.00
# ['seo', 'yandex', '18,40']
# yandex seo 18.40
# ['email', 'promo', '14,60']
# promo email 14.60
# ['seo', 'yandex', '29,80']
# yandex seo 29.80
# ['email', 'promo', '20,00']
# promo email 20.00
# ['sem', 'google', '19,00']
# google sem 19.00
# ['brand', 'google', '16,40']
# google brand 16.40
# ['sem', 'yandex', '16,20']
# yandex sem 16.20
# ['sem', 'yandex', '17,80']
# yandex sem 17.80
# ['email', 'promo', '18,80']
# promo email 18.80
# ['cpa-partners', 'burgerclub', '20,00']
# burgerclub cpa-partners 20.00
# ['seo', 'google', '21,00']
# google seo 21.00
# ['seo', 'yandex', '16,60']
# yandex seo 16.60
# ['email', 'promo', '20,00']
# promo email 20.00
# ['sem', 'yandex', '19,80']
# yandex sem 19.80
# ['email', 'promo', '16,80']
# promo email 16.80
# ['cpa-partners', 'food-delivery', '24,00']
# food-delivery cpa-partners 24.00
# ['sem', 'yandex', '12,00']
# yandex sem 12.00
# ['sem', 'yandex', '10,20']
# yandex sem 10.20
# ['email', 'promo', '24,00']
# promo email 24.00
# ['sem', 'yandex', '15,80']
# yandex sem 15.80
# ['sem', 'yandex', '22,00']
# yandex sem 22.00
# ['sem', 'google', '17,40']
# google sem 17.40
# ['sem', 'yandex', '14,80']
# yandex sem 14.80
# ['email', 'promo', '20,00']
# promo email 20.00
# ['brand', 'yandex', '11,60']
# yandex brand 11.60
# ['seo', 'yandex', '20,00']
# yandex seo 20.00
# ['sem', 'yandex', '16,00']
# yandex sem 16.00
# ['seo', 'yandex', '11,20']
# yandex seo 11.20
# ['seo', 'google', '12,20']
# google seo 12.20
# ['sem', 'yandex', '19,20']
# yandex sem 19.20
# ['sem', 'google', '17,80']
# google sem 17.80
# ['sem', 'google', '19,80']
# google sem 19.80
# ['email', 'promo', '8,60']
# promo email 8.60
# ['email', 'promo', '28,60']
# promo email 28.60
# ['email', 'newsletter', '18,80']
# newsletter email 18.80
# ['sem', 'google', '17,60']
# google sem 17.60
# ['email', 'promo', '16,00']
# promo email 16.00
# ['cpa-partners', 'food-delivery', '15,40']
# food-delivery cpa-partners 15.40
# ['sem', 'yandex', '21,60']
# yandex sem 21.60
# ['email', 'promo', '7,60']
# promo email 7.60
# ['brand', 'yandex', '21,60']
# yandex brand 21.60
# ['smm', 'facebook', '17,40']
# facebook smm 17.40
# ['sem', 'google', '22,00']
# google sem 22.00
# ['email', 'promo', '22,00']
# promo email 22.00
# ['email', 'promo', '16,00']
# promo email 16.00
# ['seo', 'yandex', '16,00']
# yandex seo 16.00
# ['sem', 'yandex', '20,00']
# yandex sem 20.00
# ['email', 'promo', '10,00']
# promo email 10.00
# ['sem', 'yandex', '21,20']
# yandex sem 21.20
# ['seo', 'yandex', '30,40']
# yandex seo 30.40
# ['cpa-partners', 'burgerclub', '18,80']
# burgerclub cpa-partners 18.80
# ['sem', 'yandex', '14,00']
# yandex sem 14.00
# ['email', 'promo', '22,00']
# promo email 22.00
# ['sem', 'google', '16,00']
# google sem 16.00
# ['sem', 'yandex', '12,60']
# yandex sem 12.60
# ['sem', 'google', '13,40']
# google sem 13.40
# ['seo', 'yandex', '13,60']
# yandex seo 13.60
# ['sem', 'yandex', '10,20']
# yandex sem 10.20
# ['brand', 'yandex', '17,40']
# yandex brand 17.40
# ['sem', 'google', '22,40']
# google sem 22.40
# ['sem', 'yandex', '11,40']
# yandex sem 11.40
# ['sem', 'google', '14,00']
# google sem 14.00
# ['seo', 'yandex', '22,40']
# yandex seo 22.40
# ['sem', 'yandex', '18,00']
# yandex sem 18.00
# ['brand', 'direct', '17,00']
# direct brand 17.00
# ['cpa-partners', 'food-delivery', '24,80']
# food-delivery cpa-partners 24.80
# ['brand', 'google', '16,60']
# google brand 16.60
# ['sem', 'google', '17,80']
# google sem 17.80
# ['sem', 'google', '9,00']
# google sem 9.00
# ['email', 'promo', '10,60']
# promo email 10.60
# ['brand', 'google', '23,40']
# google brand 23.40
# ['cpa-partners', 'burgerclub', '21,00']
# burgerclub cpa-partners 21.00
# ['email', 'promo', '16,60']
# promo email 16.60
# ['cpc-partners', 'foody', '24,20']
# foody cpc-partners 24.20
# ['seo', 'google', '20,40']
# google seo 20.40
# ['seo', 'yandex', '25,60']
# yandex seo 25.60
# ['brand', 'yandex', '19,80']
# yandex brand 19.80
# ['smm', 'facebook', '16,40']
# facebook smm 16.40
# ['email', 'promo', '16,20']
# promo email 16.20
# ['seo', 'yandex', '17,00']
# yandex seo 17.00
# ['email', 'promo', '16,80']
# promo email 16.80
# ['sem', 'yandex', '19,80']
# yandex sem 19.80
# ['seo', 'yandex', '15,60']
# yandex seo 15.60
# ['email', 'newsletter', '19,20']
# newsletter email 19.20
# ['sem', 'google', '23,20']
# google sem 23.20
# ['sem', 'yandex', '10,80']
# yandex sem 10.80
# ['sem', 'google', '24,40']
# google sem 24.40
# ['sem', 'yandex', '13,40']
# yandex sem 13.40
# ['seo', 'yandex', '12,00']
# yandex seo 12.00
# ['smm', 'facebook', '18,60']
# facebook smm 18.60
# ['sem', 'google', '16,60']
# google sem 16.60
# ['cpa-partners', 'burgerclub', '12,20']
# burgerclub cpa-partners 12.20
# ['cpa-partners', 'burgerclub', '22,40']
# burgerclub cpa-partners 22.40
# ['seo', 'google', '15,40']
# google seo 15.40
# ['cpc-partners', 'city-magazine', '17,20']
# city-magazine cpc-partners 17.20
# ['cpa-partners', 'burgerclub', '17,60']
# burgerclub cpa-partners 17.60
# ['email', 'promo', '16,40']
# promo email 16.40
# ['email', 'promo', '18,60']
# promo email 18.60
# ['email', 'promo', '19,80']
# promo email 19.80
# ['brand', 'google', '18,80']
# google brand 18.80
# ['seo', 'google', '17,60']
# google seo 17.60
# ['email', 'promo', '20,60']
# promo email 20.60
# ['cpa-partners', 'food-delivery', '15,00']
# food-delivery cpa-partners 15.00
# ['sem', 'yandex', '22,00']
# yandex sem 22.00
# ['email', 'promo', '17,40']
# promo email 17.40
# ['seo', 'yandex', '13,60']
# yandex seo 13.60
# ['seo', 'yandex', '17,60']
# yandex seo 17.60
# ['email', 'promo', '18,40']
# promo email 18.40
# ['email', 'promo', '20,40']
# promo email 20.40
# ['sem', 'yandex', '20,00']
# yandex sem 20.00
# ['brand', 'yandex', '17,80']
# yandex brand 17.80
# ['seo', 'google', '16,00']
# google seo 16.00
# ['email', 'promo', '14,60']
# promo email 14.60
# ['email', 'promo', '17,20']
# promo email 17.20
# ['sem', 'yandex', '13,60']
# yandex sem 13.60
# ['email', 'promo', '23,60']
# promo email 23.60
# ['sem', 'google', '15,60']
# google sem 15.60
# ['sem', 'yandex', '21,40']
# yandex sem 21.40
# ['sem', 'google', '13,00']
# google sem 13.00
# ['seo', 'yandex', '18,60']
# yandex seo 18.60
# ['cpa-partners', 'burgerclub', '20,60']
# burgerclub cpa-partners 20.60
# ['seo', 'yandex', '11,40']
# yandex seo 11.40
# ['email', 'promo', '18,00']
# promo email 18.00
# ['smm', 'vk', '12,00']
# vk smm 12.00
# ['sem', 'yandex', '16,00']
# yandex sem 16.00
# ['sem', 'google', '12,20']
# google sem 12.20
# ['brand', 'direct', '23,00']
# direct brand 23.00
# ['sem', 'yandex', '24,00']
# yandex sem 24.00
# ['email', 'promo', '11,80']
# promo email 11.80
# ['email', 'newsletter', '17,20']
# newsletter email 17.20
# ['email', 'newsletter', '24,60']
# newsletter email 24.60
# ['sem', 'yandex', '30,40']
# yandex sem 30.40
# ['sem', 'yandex', '18,00']
# yandex sem 18.00
# ['email', 'promo', '15,00']
# promo email 15.00
# ['sem', 'google', '13,20']
# google sem 13.20
# ['seo', 'yandex', '28,80']
# yandex seo 28.80
# ['sem', 'yandex', '22,00']
# yandex sem 22.00
# ['email', 'promo', '15,60']
# promo email 15.60
# ['sem', 'yandex', '13,60']
# yandex sem 13.60
# ['sem', 'google', '8,60']
# google sem 8.60
# ['sem', 'google', '22,00']
# google sem 22.00
# ['email', 'promo', '20,00']
# promo email 20.00
# ['sem', 'yandex', '12,60']
# yandex sem 12.60
# ['sem', 'google', '18,00']
# google sem 18.00
# ['brand', 'direct', '11,00']
# direct brand 11.00
# ['email', 'promo', '12,20']
# promo email 12.20
# ['sem', 'yandex', '18,00']
# yandex sem 18.00
# ['email', 'promo', '12,40']
# promo email 12.40
# ['seo', 'google', '13,00']
# google seo 13.00
# ['brand', 'direct', '21,40']
# direct brand 21.40
# ['sem', 'yandex', '13,60']
# yandex sem 13.60
# ['cpa-partners', 'food-delivery', '17,40']
# food-delivery cpa-partners 17.40
# ['sem', 'google', '15,00']
# google sem 15.00
# ['seo', 'yandex', '14,40']
# yandex seo 14.40
# ['brand', 'direct', '16,00']
# direct brand 16.00
# ['seo', 'yandex', '12,00']
# yandex seo 12.00
# ['sem', 'yandex', '12,80']
# yandex sem 12.80
# ['email', 'promo', '21,40']
# promo email 21.40
# ['sem', 'yandex', '17,40']
# yandex sem 17.40
# ['sem', 'yandex', '21,60']
# yandex sem 21.60
# ['email', 'promo', '16,00']
# promo email 16.00
# ['sem', 'google', '16,40']
# google sem 16.40
# ['sem', 'yandex', '16,00']
# yandex sem 16.00
# ['email', 'promo', '22,00']
# promo email 22.00
# ['brand', 'yandex', '21,80']
# yandex brand 21.80
# ['email', 'promo', '14,60']
# promo email 14.60
# ['seo', 'yandex', '22,00']
# yandex seo 22.00
# ['email', 'promo', '25,00']
# promo email 25.00
# ['sem', 'google', '15,60']
# google sem 15.60
# ['email', 'promo', '17,80']
# promo email 17.80
# ['sem', 'yandex', '14,80']
# yandex sem 14.80
# ['sem', 'yandex', '18,20']
# yandex sem 18.20
# ['sem', 'google', '12,60']
# google sem 12.60
# ['email', 'promo', '11,80']
# promo email 11.80
# ['sem', 'yandex', '16,00']
# yandex sem 16.00
# ['seo', 'yandex', '30,40']
# yandex seo 30.40
# ['seo', 'google', '13,40']
# google seo 13.40
# ['email', 'newsletter', '18,40']
# newsletter email 18.40
# ['email', 'promo', '20,00']
# promo email 20.00
# ['smm', 'vk', '17,00']
# vk smm 17.00
# ['sem', 'google', '26,00']
# google sem 26.00
# ['sem', 'google', '21,00']
# google sem 21.00
# ['cpc-partners', 'foody', '19,40']
# foody cpc-partners 19.40
# ['sem', 'yandex', '16,00']
# yandex sem 16.00
# ['sem', 'yandex', '12,80']
# yandex sem 12.80
# ['sem', 'google', '14,00']
# google sem 14.00
# ['cpa-partners', 'burgerclub', '21,80']
# burgerclub cpa-partners 21.80
# ['cpc-partners', 'city-magazine', '11,80']
# city-magazine cpc-partners 11.80
# ['sem', 'google', '25,80']
# google sem 25.80
# ['sem', 'google', '18,00']
# google sem 18.00
# ['sem', 'google', '10,20']
# google sem 10.20
# ['email', 'promo', '12,00']
# promo email 12.00
# ['sem', 'google', '13,80']
# google sem 13.80
# ['sem', 'google', '16,60']
# google sem 16.60
# ['sem', 'google', '11,40']
# google sem 11.40
# ['brand', 'google', '13,40']
# google brand 13.40
# ['sem', 'yandex', '14,00']
# yandex sem 14.00
# ['sem', 'google', '16,60']
# google sem 16.60
# ['email', 'promo', '24,00']
# promo email 24.00
# ['email', 'promo', '10,20']
# promo email 10.20
# ['email', 'promo', '18,60']
# promo email 18.60
# ['sem', 'yandex', '21,60']
# yandex sem 21.60
# ['cpa-partners', 'burgerclub', '20,20']
# burgerclub cpa-partners 20.20
# ['sem', 'yandex', '18,00']
# yandex sem 18.00
# ['email', 'promo', '17,40']
# promo email 17.40
# ['email', 'promo', '22,00']
# promo email 22.00
# ['sem', 'yandex', '17,40']
# yandex sem 17.40
# ['sem', 'yandex', '19,00']
# yandex sem 19.00
# ['smm', 'facebook', '18,00']
# facebook smm 18.00
# ['brand', 'google', '16,00']
# google brand 16.00
# ['email', 'promo', '28,60']
# promo email 28.60
# ['sem', 'yandex', '18,40']
# yandex sem 18.40
# ['email', 'promo', '18,80']
# promo email 18.80
# ['seo', 'yandex', '17,80']
# yandex seo 17.80
# ['sem', 'yandex', '16,80']
# yandex sem 16.80
# ['sem', 'yandex', '19,40']
# yandex sem 19.40
# ['sem', 'google', '20,00']
# google sem 20.00
# ['sem', 'yandex', '16,00']
# yandex sem 16.00
# ['sem', 'google', '22,00']
# google sem 22.00
# ['cpa-partners', 'food-delivery', '12,80']
# food-delivery cpa-partners 12.80
# ['email', 'promo', '20,00']
# promo email 20.00
# ['sem', 'yandex', '17,40']
# yandex sem 17.40
# ['email', 'promo', '15,60']
# promo email 15.60
# ['sem', 'google', '22,00']
# google sem 22.00
# ['sem', 'google', '14,40']
# google sem 14.40
# ['sem', 'google', '12,20']
# google sem 12.20
# ['seo', 'yandex', '12,20']
# yandex seo 12.20
# ['email', 'promo', '20,00']
# promo email 20.00
# ['cpa-partners', 'food-delivery', '13,00']
# food-delivery cpa-partners 13.00
# ['sem', 'yandex', '22,40']
# yandex sem 22.40
# ['sem', 'yandex', '13,60']
# yandex sem 13.60
# ['sem', 'google', '30,40']
# google sem 30.40
# ['sem', 'yandex', '12,40']
# yandex sem 12.40
# ['sem', 'yandex', '16,00']
# yandex sem 16.00
# ['seo', 'yandex', '30,40']
# yandex seo 30.40
# ['cpc-partners', 'city-magazine', '23,20']
# city-magazine cpc-partners 23.20
# ['sem', 'google', '20,00']
# google sem 20.00
# ['email', 'promo', '12,60']
# promo email 12.60
# ['sem', 'google', '14,60']
# google sem 14.60
# ['cpc-partners', 'city-magazine', '11,80']
# city-magazine cpc-partners 11.80
# ['smm', 'facebook', '20,20']
# facebook smm 20.20
# ['sem', 'google', '10,00']
# google sem 10.00
# ['email', 'promo', '12,80']
# promo email 12.80
# ['sem', 'yandex', '20,60']
# yandex sem 20.60
# ['seo', 'yandex', '18,00']
# yandex seo 18.00
# ['cpa-partners', 'food-delivery', '13,80']
# food-delivery cpa-partners 13.80
# ['seo', 'yandex', '12,80']
# yandex seo 12.80
# ['sem', 'yandex', '17,20']
# yandex sem 17.20
# ['sem', 'google', '16,00']
# google sem 16.00
# ['email', 'promo', '14,20']
# promo email 14.20
# ['sem', 'yandex', '19,60']
# yandex sem 19.60
# ['seo', 'google', '22,40']
# google seo 22.40
# ['email', 'promo', '14,80']
# promo email 14.80
# ['sem', 'google', '13,00']
# google sem 13.00
# ['sem', 'google', '13,60']
# google sem 13.60
# ['email', 'promo', '12,60']
# promo email 12.60
# ['seo', 'yandex', '19,20']
# yandex seo 19.20
# ['email', 'promo', '20,20']
# promo email 20.20
# ['sem', 'google', '16,00']
# google sem 16.00
# ['sem', 'yandex', '11,60']
# yandex sem 11.60

# %%
type( amount_paid )
# Out:
# str

# %%
with open( 'data_3_columns.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        

        medium = line[0]

        source = line[1]

        amount_paid = float( line[2].replace(',', '.') )

        

        print( source, medium, amount_paid )
# Out:
# google seo 20.2
# yandex sem 15.6
# promo email 13.2
# yandex sem 9.8
# google sem 14.8
# google sem 14.4
# google sem 14.0
# yandex brand 20.0
# yandex sem 16.2
# promo email 11.0
# burgerclub cpa-partners 10.8
# google seo 22.6
# google seo 22.4
# yandex sem 24.4
# google seo 16.6
# yandex sem 8.6
# yandex seo 12.4
# food-delivery cpa-partners 16.2
# promo email 24.0
# yandex sem 18.8
# promo email 11.8
# google sem 9.4
# google sem 11.2
# promo email 19.0
# google sem 23.4
# city-magazine cpc-partners 17.0
# google seo 20.8
# promo email 15.6
# foody cpc-partners 22.4
# yandex seo 15.6
# food-delivery cpa-partners 21.0
# google seo 22.4
# google sem 20.4
# promo email 26.0
# yandex seo 18.4
# promo email 14.6
# yandex seo 29.8
# promo email 20.0
# google sem 19.0
# google brand 16.4
# yandex sem 16.2
# yandex sem 17.8
# promo email 18.8
# burgerclub cpa-partners 20.0
# google seo 21.0
# yandex seo 16.6
# promo email 20.0
# yandex sem 19.8
# promo email 16.8
# food-delivery cpa-partners 24.0
# yandex sem 12.0
# yandex sem 10.2
# promo email 24.0
# yandex sem 15.8
# yandex sem 22.0
# google sem 17.4
# yandex sem 14.8
# promo email 20.0
# yandex brand 11.6
# yandex seo 20.0
# yandex sem 16.0
# yandex seo 11.2
# google seo 12.2
# yandex sem 19.2
# google sem 17.8
# google sem 19.8
# promo email 8.6
# promo email 28.6
# newsletter email 18.8
# google sem 17.6
# promo email 16.0
# food-delivery cpa-partners 15.4
# yandex sem 21.6
# promo email 7.6
# yandex brand 21.6
# facebook smm 17.4
# google sem 22.0
# promo email 22.0
# promo email 16.0
# yandex seo 16.0
# yandex sem 20.0
# promo email 10.0
# yandex sem 21.2
# yandex seo 30.4
# burgerclub cpa-partners 18.8
# yandex sem 14.0
# promo email 22.0
# google sem 16.0
# yandex sem 12.6
# google sem 13.4
# yandex seo 13.6
# yandex sem 10.2
# yandex brand 17.4
# google sem 22.4
# yandex sem 11.4
# google sem 14.0
# yandex seo 22.4
# yandex sem 18.0
# direct brand 17.0
# food-delivery cpa-partners 24.8
# google brand 16.6
# google sem 17.8
# google sem 9.0
# promo email 10.6
# google brand 23.4
# burgerclub cpa-partners 21.0
# promo email 16.6
# foody cpc-partners 24.2
# google seo 20.4
# yandex seo 25.6
# yandex brand 19.8
# facebook smm 16.4
# promo email 16.2
# yandex seo 17.0
# promo email 16.8
# yandex sem 19.8
# yandex seo 15.6
# newsletter email 19.2
# google sem 23.2
# yandex sem 10.8
# google sem 24.4
# yandex sem 13.4
# yandex seo 12.0
# facebook smm 18.6
# google sem 16.6
# burgerclub cpa-partners 12.2
# burgerclub cpa-partners 22.4
# google seo 15.4
# city-magazine cpc-partners 17.2
# burgerclub cpa-partners 17.6
# promo email 16.4
# promo email 18.6
# promo email 19.8
# google brand 18.8
# google seo 17.6
# promo email 20.6
# food-delivery cpa-partners 15.0
# yandex sem 22.0
# promo email 17.4
# yandex seo 13.6
# yandex seo 17.6
# promo email 18.4
# promo email 20.4
# yandex sem 20.0
# yandex brand 17.8
# google seo 16.0
# promo email 14.6
# promo email 17.2
# yandex sem 13.6
# promo email 23.6
# google sem 15.6
# yandex sem 21.4
# google sem 13.0
# yandex seo 18.6
# burgerclub cpa-partners 20.6
# yandex seo 11.4
# promo email 18.0
# vk smm 12.0
# yandex sem 16.0
# google sem 12.2
# direct brand 23.0
# yandex sem 24.0
# promo email 11.8
# newsletter email 17.2
# newsletter email 24.6
# yandex sem 30.4
# yandex sem 18.0
# promo email 15.0
# google sem 13.2
# yandex seo 28.8
# yandex sem 22.0
# promo email 15.6
# yandex sem 13.6
# google sem 8.6
# google sem 22.0
# promo email 20.0
# yandex sem 12.6
# google sem 18.0
# direct brand 11.0
# promo email 12.2
# yandex sem 18.0
# promo email 12.4
# google seo 13.0
# direct brand 21.4
# yandex sem 13.6
# food-delivery cpa-partners 17.4
# google sem 15.0
# yandex seo 14.4
# direct brand 16.0
# yandex seo 12.0
# yandex sem 12.8
# promo email 21.4
# yandex sem 17.4
# yandex sem 21.6
# promo email 16.0
# google sem 16.4
# yandex sem 16.0
# promo email 22.0
# yandex brand 21.8
# promo email 14.6
# yandex seo 22.0
# promo email 25.0
# google sem 15.6
# promo email 17.8
# yandex sem 14.8
# yandex sem 18.2
# google sem 12.6
# promo email 11.8
# yandex sem 16.0
# yandex seo 30.4
# google seo 13.4
# newsletter email 18.4
# promo email 20.0
# vk smm 17.0
# google sem 26.0
# google sem 21.0
# foody cpc-partners 19.4
# yandex sem 16.0
# yandex sem 12.8
# google sem 14.0
# burgerclub cpa-partners 21.8
# city-magazine cpc-partners 11.8
# google sem 25.8
# google sem 18.0
# google sem 10.2
# promo email 12.0
# google sem 13.8
# google sem 16.6
# google sem 11.4
# google brand 13.4
# yandex sem 14.0
# google sem 16.6
# promo email 24.0
# promo email 10.2
# promo email 18.6
# yandex sem 21.6
# burgerclub cpa-partners 20.2
# yandex sem 18.0
# promo email 17.4
# promo email 22.0
# yandex sem 17.4
# yandex sem 19.0
# facebook smm 18.0
# google brand 16.0
# promo email 28.6
# yandex sem 18.4
# promo email 18.8
# yandex seo 17.8
# yandex sem 16.8
# yandex sem 19.4
# google sem 20.0
# yandex sem 16.0
# google sem 22.0
# food-delivery cpa-partners 12.8
# promo email 20.0
# yandex sem 17.4
# promo email 15.6
# google sem 22.0
# google sem 14.4
# google sem 12.2
# yandex seo 12.2
# promo email 20.0
# food-delivery cpa-partners 13.0
# yandex sem 22.4
# yandex sem 13.6
# google sem 30.4
# yandex sem 12.4
# yandex sem 16.0
# yandex seo 30.4
# city-magazine cpc-partners 23.2
# google sem 20.0
# promo email 12.6
# google sem 14.6
# city-magazine cpc-partners 11.8
# facebook smm 20.2
# google sem 10.0
# promo email 12.8
# yandex sem 20.6
# yandex seo 18.0
# food-delivery cpa-partners 13.8
# yandex seo 12.8
# yandex sem 17.2
# google sem 16.0
# promo email 14.2
# yandex sem 19.6
# google seo 22.4
# promo email 14.8
# google sem 13.0
# google sem 13.6
# promo email 12.6
# yandex seo 19.2
# promo email 20.2
# google sem 16.0
# yandex sem 11.6

# %%
total_sum = 0

with open( 'data_3_columns.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        amount_paid = float( line[2].replace(',', '.') )

        total_sum += amount_paid

        print( 'Текущая сумма расходов: {:.2f}'.format( total_sum ) )
# Out:
# Текущая сумма расходов: 20.20
# Текущая сумма расходов: 35.80
# Текущая сумма расходов: 49.00
# Текущая сумма расходов: 58.80
# Текущая сумма расходов: 73.60
# Текущая сумма расходов: 88.00
# Текущая сумма расходов: 102.00
# Текущая сумма расходов: 122.00
# Текущая сумма расходов: 138.20
# Текущая сумма расходов: 149.20
# Текущая сумма расходов: 160.00
# Текущая сумма расходов: 182.60
# Текущая сумма расходов: 205.00
# Текущая сумма расходов: 229.40
# Текущая сумма расходов: 246.00
# Текущая сумма расходов: 254.60
# Текущая сумма расходов: 267.00
# Текущая сумма расходов: 283.20
# Текущая сумма расходов: 307.20
# Текущая сумма расходов: 326.00
# Текущая сумма расходов: 337.80
# Текущая сумма расходов: 347.20
# Текущая сумма расходов: 358.40
# Текущая сумма расходов: 377.40
# Текущая сумма расходов: 400.80
# Текущая сумма расходов: 417.80
# Текущая сумма расходов: 438.60
# Текущая сумма расходов: 454.20
# Текущая сумма расходов: 476.60
# Текущая сумма расходов: 492.20
# Текущая сумма расходов: 513.20
# Текущая сумма расходов: 535.60
# Текущая сумма расходов: 556.00
# Текущая сумма расходов: 582.00
# Текущая сумма расходов: 600.40
# Текущая сумма расходов: 615.00
# Текущая сумма расходов: 644.80
# Текущая сумма расходов: 664.80
# Текущая сумма расходов: 683.80
# Текущая сумма расходов: 700.20
# Текущая сумма расходов: 716.40
# Текущая сумма расходов: 734.20
# Текущая сумма расходов: 753.00
# Текущая сумма расходов: 773.00
# Текущая сумма расходов: 794.00
# Текущая сумма расходов: 810.60
# Текущая сумма расходов: 830.60
# Текущая сумма расходов: 850.40
# Текущая сумма расходов: 867.20
# Текущая сумма расходов: 891.20
# Текущая сумма расходов: 903.20
# Текущая сумма расходов: 913.40
# Текущая сумма расходов: 937.40
# Текущая сумма расходов: 953.20
# Текущая сумма расходов: 975.20
# Текущая сумма расходов: 992.60
# Текущая сумма расходов: 1007.40
# Текущая сумма расходов: 1027.40
# Текущая сумма расходов: 1039.00
# Текущая сумма расходов: 1059.00
# Текущая сумма расходов: 1075.00
# Текущая сумма расходов: 1086.20
# Текущая сумма расходов: 1098.40
# Текущая сумма расходов: 1117.60
# Текущая сумма расходов: 1135.40
# Текущая сумма расходов: 1155.20
# Текущая сумма расходов: 1163.80
# Текущая сумма расходов: 1192.40
# Текущая сумма расходов: 1211.20
# Текущая сумма расходов: 1228.80
# Текущая сумма расходов: 1244.80
# Текущая сумма расходов: 1260.20
# Текущая сумма расходов: 1281.80
# Текущая сумма расходов: 1289.40
# Текущая сумма расходов: 1311.00
# Текущая сумма расходов: 1328.40
# Текущая сумма расходов: 1350.40
# Текущая сумма расходов: 1372.40
# Текущая сумма расходов: 1388.40
# Текущая сумма расходов: 1404.40
# Текущая сумма расходов: 1424.40
# Текущая сумма расходов: 1434.40
# Текущая сумма расходов: 1455.60
# Текущая сумма расходов: 1486.00
# Текущая сумма расходов: 1504.80
# Текущая сумма расходов: 1518.80
# Текущая сумма расходов: 1540.80
# Текущая сумма расходов: 1556.80
# Текущая сумма расходов: 1569.40
# Текущая сумма расходов: 1582.80
# Текущая сумма расходов: 1596.40
# Текущая сумма расходов: 1606.60
# Текущая сумма расходов: 1624.00
# Текущая сумма расходов: 1646.40
# Текущая сумма расходов: 1657.80
# Текущая сумма расходов: 1671.80
# Текущая сумма расходов: 1694.20
# Текущая сумма расходов: 1712.20
# Текущая сумма расходов: 1729.20
# Текущая сумма расходов: 1754.00
# Текущая сумма расходов: 1770.60
# Текущая сумма расходов: 1788.40
# Текущая сумма расходов: 1797.40
# Текущая сумма расходов: 1808.00
# Текущая сумма расходов: 1831.40
# Текущая сумма расходов: 1852.40
# Текущая сумма расходов: 1869.00
# Текущая сумма расходов: 1893.20
# Текущая сумма расходов: 1913.60
# Текущая сумма расходов: 1939.20
# Текущая сумма расходов: 1959.00
# Текущая сумма расходов: 1975.40
# Текущая сумма расходов: 1991.60
# Текущая сумма расходов: 2008.60
# Текущая сумма расходов: 2025.40
# Текущая сумма расходов: 2045.20
# Текущая сумма расходов: 2060.80
# Текущая сумма расходов: 2080.00
# Текущая сумма расходов: 2103.20
# Текущая сумма расходов: 2114.00
# Текущая сумма расходов: 2138.40
# Текущая сумма расходов: 2151.80
# Текущая сумма расходов: 2163.80
# Текущая сумма расходов: 2182.40
# Текущая сумма расходов: 2199.00
# Текущая сумма расходов: 2211.20
# Текущая сумма расходов: 2233.60
# Текущая сумма расходов: 2249.00
# Текущая сумма расходов: 2266.20
# Текущая сумма расходов: 2283.80
# Текущая сумма расходов: 2300.20
# Текущая сумма расходов: 2318.80
# Текущая сумма расходов: 2338.60
# Текущая сумма расходов: 2357.40
# Текущая сумма расходов: 2375.00
# Текущая сумма расходов: 2395.60
# Текущая сумма расходов: 2410.60
# Текущая сумма расходов: 2432.60
# Текущая сумма расходов: 2450.00
# Текущая сумма расходов: 2463.60
# Текущая сумма расходов: 2481.20
# Текущая сумма расходов: 2499.60
# Текущая сумма расходов: 2520.00
# Текущая сумма расходов: 2540.00
# Текущая сумма расходов: 2557.80
# Текущая сумма расходов: 2573.80
# Текущая сумма расходов: 2588.40
# Текущая сумма расходов: 2605.60
# Текущая сумма расходов: 2619.20
# Текущая сумма расходов: 2642.80
# Текущая сумма расходов: 2658.40
# Текущая сумма расходов: 2679.80
# Текущая сумма расходов: 2692.80
# Текущая сумма расходов: 2711.40
# Текущая сумма расходов: 2732.00
# Текущая сумма расходов: 2743.40
# Текущая сумма расходов: 2761.40
# Текущая сумма расходов: 2773.40
# Текущая сумма расходов: 2789.40
# Текущая сумма расходов: 2801.60
# Текущая сумма расходов: 2824.60
# Текущая сумма расходов: 2848.60
# Текущая сумма расходов: 2860.40
# Текущая сумма расходов: 2877.60
# Текущая сумма расходов: 2902.20
# Текущая сумма расходов: 2932.60
# Текущая сумма расходов: 2950.60
# Текущая сумма расходов: 2965.60
# Текущая сумма расходов: 2978.80
# Текущая сумма расходов: 3007.60
# Текущая сумма расходов: 3029.60
# Текущая сумма расходов: 4510.00
# Текущая сумма расходов: 4532.00
# Текущая сумма расходов: 4546.40
# Текущая сумма расходов: 4558.60
# Текущая сумма расходов: 4570.80
# Текущая сумма расходов: 4590.80
# Текущая сумма расходов: 4603.80
# Текущая сумма расходов: 4626.20
# Текущая сумма расходов: 4639.80
# Текущая сумма расходов: 4670.20
# Текущая сумма расходов: 4682.60
# Текущая сумма расходов: 4698.60
# Текущая сумма расходов: 4729.00
# Текущая сумма расходов: 4752.20
# Текущая сумма расходов: 4772.20
# Текущая сумма расходов: 4784.80
# Текущая сумма расходов: 4799.40
# Текущая сумма расходов: 4811.20
# Текущая сумма расходов: 4831.40
# Текущая сумма расходов: 4841.40
# Текущая сумма расходов: 4854.20
# Текущая сумма расходов: 4874.80
# Текущая сумма расходов: 4892.80
# Текущая сумма расходов: 4906.60
# Текущая сумма расходов: 4919.40
# Текущая сумма расходов: 4936.60
# Текущая сумма расходов: 4952.60
# Текущая сумма расходов: 4966.80
# Текущая сумма расходов: 4986.40
# Текущая сумма расходов: 5008.80
# Текущая сумма расходов: 5023.60
# Текущая сумма расходов: 5036.60
# Текущая сумма расходов: 5050.20
# Текущая сумма расходов: 5062.80
# Текущая сумма расходов: 5082.00
# Текущая сумма расходов: 5102.20
# Текущая сумма расходов: 5118.20
# Текущая сумма расходов: 5129.80

# %%
total_sum = 0

with open( 'data_3_columns.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        

        medium = line[0]

        source = line[1]

        amount_paid = float( line[2].replace(',', '.') )

        

        if source == 'google':

            total_sum += amount_paid

            print( 'Текущая сумма расходов google: {:.2f}'.format( total_sum ) )
# Out:
# Текущая сумма расходов google: 20.20
# Текущая сумма расходов google: 35.00
# Текущая сумма расходов google: 49.40
# Текущая сумма расходов google: 63.40
# Текущая сумма расходов google: 86.00
# Текущая сумма расходов google: 108.40
# Текущая сумма расходов google: 125.00
# Текущая сумма расходов google: 134.40
# Текущая сумма расходов google: 145.60
# Текущая сумма расходов google: 169.00
# Текущая сумма расходов google: 189.80
# Текущая сумма расходов google: 212.20
# Текущая сумма расходов google: 232.60
# Текущая сумма расходов google: 251.60
# Текущая сумма расходов google: 268.00
# Текущая сумма расходов google: 289.00
# Текущая сумма расходов google: 306.40
# Текущая сумма расходов google: 318.60
# Текущая сумма расходов google: 336.40
# Текущая сумма расходов google: 356.20
# Текущая сумма расходов google: 373.80
# Текущая сумма расходов google: 395.80
# Текущая сумма расходов google: 411.80
# Текущая сумма расходов google: 425.20
# Текущая сумма расходов google: 447.60
# Текущая сумма расходов google: 461.60
# Текущая сумма расходов google: 478.20
# Текущая сумма расходов google: 496.00
# Текущая сумма расходов google: 505.00
# Текущая сумма расходов google: 528.40
# Текущая сумма расходов google: 548.80
# Текущая сумма расходов google: 572.00
# Текущая сумма расходов google: 596.40
# Текущая сумма расходов google: 613.00
# Текущая сумма расходов google: 628.40
# Текущая сумма расходов google: 647.20
# Текущая сумма расходов google: 664.80
# Текущая сумма расходов google: 680.80
# Текущая сумма расходов google: 696.40
# Текущая сумма расходов google: 709.40
# Текущая сумма расходов google: 721.60
# Текущая сумма расходов google: 734.80
# Текущая сумма расходов google: 743.40
# Текущая сумма расходов google: 765.40
# Текущая сумма расходов google: 783.40
# Текущая сумма расходов google: 796.40
# Текущая сумма расходов google: 811.40
# Текущая сумма расходов google: 827.80
# Текущая сумма расходов google: 843.40
# Текущая сумма расходов google: 856.00
# Текущая сумма расходов google: 869.40
# Текущая сумма расходов google: 895.40
# Текущая сумма расходов google: 916.40
# Текущая сумма расходов google: 930.40
# Текущая сумма расходов google: 956.20
# Текущая сумма расходов google: 974.20
# Текущая сумма расходов google: 984.40
# Текущая сумма расходов google: 998.20
# Текущая сумма расходов google: 1014.80
# Текущая сумма расходов google: 1026.20
# Текущая сумма расходов google: 1039.60
# Текущая сумма расходов google: 1056.20
# Текущая сумма расходов google: 1072.20
# Текущая сумма расходов google: 1092.20
# Текущая сумма расходов google: 1114.20
# Текущая сумма расходов google: 1136.20
# Текущая сумма расходов google: 1150.60
# Текущая сумма расходов google: 1162.80
# Текущая сумма расходов google: 1193.20
# Текущая сумма расходов google: 1213.20
# Текущая сумма расходов google: 1227.80
# Текущая сумма расходов google: 1237.80
# Текущая сумма расходов google: 1253.80
# Текущая сумма расходов google: 1276.20
# Текущая сумма расходов google: 1289.20
# Текущая сумма расходов google: 1302.80
# Текущая сумма расходов google: 1318.80

# %%
total_sum = 0

with open( 'data_3_columns.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        

        medium = line[0]

        source = line[1]

        amount_paid = float( line[2].replace(',', '.') )

        

        if source == 'yandex' and medium == 'seo':

            total_sum += amount_paid

            print( 'Текущая сумма расходов google: {:.2f}'.format( total_sum ) )
# Out:
# Текущая сумма расходов google: 12.40
# Текущая сумма расходов google: 28.00
# Текущая сумма расходов google: 46.40
# Текущая сумма расходов google: 76.20
# Текущая сумма расходов google: 92.80
# Текущая сумма расходов google: 112.80
# Текущая сумма расходов google: 124.00
# Текущая сумма расходов google: 140.00
# Текущая сумма расходов google: 170.40
# Текущая сумма расходов google: 184.00
# Текущая сумма расходов google: 206.40
# Текущая сумма расходов google: 232.00
# Текущая сумма расходов google: 249.00
# Текущая сумма расходов google: 264.60
# Текущая сумма расходов google: 276.60
# Текущая сумма расходов google: 290.20
# Текущая сумма расходов google: 307.80
# Текущая сумма расходов google: 326.40
# Текущая сумма расходов google: 337.80
# Текущая сумма расходов google: 366.60
# Текущая сумма расходов google: 381.00
# Текущая сумма расходов google: 393.00
# Текущая сумма расходов google: 415.00
# Текущая сумма расходов google: 445.40
# Текущая сумма расходов google: 463.20
# Текущая сумма расходов google: 475.40
# Текущая сумма расходов google: 505.80
# Текущая сумма расходов google: 523.80
# Текущая сумма расходов google: 536.60
# Текущая сумма расходов google: 555.80

# %%
import openpyxl

# %%
workbook = 'data.xlsx'

sheetName = 'data'

# %%
sheet = openpyxl.load_workbook( workbook )[sheetName]

# %%
for line in sheet[ 'A1:I1' ]:

    print( line )
# Out:
# (<Cell 'data'.A1>, <Cell 'data'.B1>, <Cell 'data'.C1>, <Cell 'data'.D1>, <Cell 'data'.E1>, <Cell 'data'.F1>, <Cell 'data'.G1>, <Cell 'data'.H1>, <Cell 'data'.I1>)

# %%
line[0].value
# Out:
# 'id'

# %%
line[4].value
# Out:
# 'medium'

# %%
for line in sheet[ 'E2:I5' ]:

    medium = line[0].value

    source = line[1].value

    amount_paid = line[4].value

    print( source, medium, amount_paid )
# Out:
# google seo 20.2
# yandex sem 15.6
# promo email 13.2
# yandex sem 9.8

# %%
type(amount_paid)
# Out:
# float

# %%
total_amount_paid = 0

for line in sheet[ 'E2:I295' ]:  

    amount_paid = line[4].value
    total_amount_paid += amount_paid

# %%
total_amount_paid
# Out:
# 5129.8

# %%
allowedMedium = [ 'brand', 'seo' ]

#Значение source пока просто запишем как одно значение:

allowedSource = 'yandex'

# %%
Started = True

with open( 'data.txt', 'r' ) as f:

    for line in f:

        if Started:

            Started = False

        else:

            line = line.strip().split('\t')

            print( line )
# Out:
# ['40443', '05.10.2016 23:18', '1010', '0,000925926', 'seo', 'google', '0', '6243', '20,20']
# ['35044', '09.10.2016 21:40', '1036', '0,006493056', 'sem', 'yandex', '0,07', '6145', '15,60']
# ['40177', '05.10.2016 3:23', '1041', '0,00337963', 'email', 'promo', '0', '6128', '13,20']
# ['39401', '05.10.2016 23:19', '1041', '0,000462963', 'sem', 'yandex', '0,03', '6697', '9,80']
# ['41545', '01.10.2016 4:57', '1042', '0,006493056', 'sem', 'google', '0,06', '4510', '14,80']
# ['38308', '01.10.2016 23:29', '1042', '0,00337963', 'sem', 'google', '0,06', '2622', '14,40']
# ['35921', '03.10.2016 20:20', '1042', '0,001388889', 'sem', 'google', '0,12', '2663', '14,00']
# ['41783', '04.10.2016 0:35', '1042', '0,001643519', 'brand', 'yandex', '0', '2582', '20,00']
# ['42099', '04.10.2016 13:46', '1042', '0,001921296', 'sem', 'yandex', '0,11', '2619', '16,20']
# ['38328', '04.10.2016 17:34', '1042', '0,003287037', 'email', 'promo', '0', '2598', '11,00']
# ['40986', '05.10.2016 15:15', '1042', '0,001643519', 'cpa-partners', 'burgerclub', '0,88', '3993', '10,80']
# ['41809', '06.10.2016 20:45', '1042', '0,001921296', 'seo', 'google', '0', '4421', '22,60']
# ['40804', '07.10.2016 2:54', '1042', '0,006493056', 'seo', 'google', '0', '2704', '22,40']
# ['37729', '07.10.2016 5:02', '1042', '0,003287037', 'sem', 'yandex', '0,11', '3441', '24,40']
# ['37274', '07.10.2016 6:35', '1042', '0,003842593', 'seo', 'google', '0', '3637', '16,60']
# ['37711', '08.10.2016 16:46', '1042', '0,000462963', 'sem', 'yandex', '0,03', '2599', '8,60']
# ['35331', '01.10.2016 13:39', '1047', '0,001921296', 'seo', 'yandex', '0', '4182', '12,40']
# ['40842', '05.10.2016 21:41', '1047', '0,001643519', 'cpa-partners', 'food-delivery', '1,86', '3802', '16,20']
# ['39418', '07.10.2016 9:59', '1052', '0,000821759', 'email', 'promo', '0', '4217', '24,00']
# ['35805', '08.10.2016 19:36', '1052', '0,001921296', 'sem', 'yandex', '0,04', '3842', '18,80']
# ['37794', '04.10.2016 11:12', '1057', '0,000821759', 'email', 'promo', '0', '3870', '11,80']
# ['41669', '09.10.2016 2:47', '1057', '0,003842593', 'sem', 'google', '0,19', '4324', '9,40']
# ['40626', '09.10.2016 16:27', '1062', '0,003287037', 'sem', 'google', '0,1', '6072', '11,20']
# ['39741', '05.10.2016 4:38', '1067', '0,003287037', 'email', 'promo', '0', '6678', '19,00']
# ['41732', '04.10.2016 9:56', '1078', '0,006759259', 'sem', 'google', '0,21', '6274', '23,40']
# ['41894', '04.10.2016 14:36', '1085', '0,001921296', 'cpc-partners', 'city-magazine', '0,15', '6098', '17,00']
# ['38909', '05.10.2016 16:41', '1096', '0,003287037', 'seo', 'google', '0', '6389', '20,80']
# ['41626', '01.10.2016 11:55', '1098', '0,001643519', 'email', 'promo', '0', '6654', '15,60']
# ['42106', '01.10.2016 14:16', '1100', '0,001388889', 'cpc-partners', 'foody', '0,1', '2320', '22,40']
# ['39548', '02.10.2016 1:39', '1100', '0,000462963', 'seo', 'yandex', '0', '2210', '15,60']
# ['38228', '02.10.2016 2:49', '1100', '0,000821759', 'cpa-partners', 'food-delivery', '2,34', '3615', '21,00']
# ['36938', '02.10.2016 13:05', '1100', '0,006493056', 'seo', 'google', '0', '2358', '22,40']
# ['35958', '03.10.2016 4:04', '1100', '0,006759259', 'sem', 'google', '0,07', '3940', '20,40']
# ['42107', '03.10.2016 6:58', '1100', '0,000821759', 'email', 'promo', '0', '2389', '26,00']
# ['41255', '03.10.2016 15:01', '1100', '0,00337963', 'seo', 'yandex', '0', '2314', '18,40']
# ['36114', '04.10.2016 23:43', '1100', '0,003287037', 'email', 'promo', '0', '2187', '14,60']
# ['36328', '05.10.2016 5:46', '1100', '0,001921296', 'seo', 'yandex', '0', '2228', '29,80']
# ['39771', '06.10.2016 0:31', '1100', '0,001643519', 'email', 'promo', '0', '4390', '20,00']
# ['42145', '06.10.2016 9:25', '1100', '0,000821759', 'sem', 'google', '0,14', '2391', '19,00']
# ['39460', '08.10.2016 15:15', '1100', '0,012986111', 'brand', 'google', '0', '3413', '16,40']
# ['38259', '07.10.2016 9:06', '1105', '0,00337963', 'sem', 'yandex', '0,12', '6438', '16,20']
# ['37585', '01.10.2016 4:30', '1108', '0,000821759', 'sem', 'yandex', '0,22', '2762', '17,80']
# ['36912', '01.10.2016 18:16', '1108', '0,001643519', 'email', 'promo', '0', '4027', '18,80']
# ['41581', '02.10.2016 2:58', '1108', '0,000462963', 'cpa-partners', 'burgerclub', '1,312', '3474', '20,00']
# ['39205', '02.10.2016 6:01', '1108', '0,000821759', 'seo', 'google', '0', '2770', '21,00']
# ['41424', '02.10.2016 20:03', '1108', '0,003842593', 'seo', 'yandex', '0', '2931', '16,60']
# ['40222', '04.10.2016 2:56', '1108', '0,001643519', 'email', 'promo', '0', '2869', '20,00']
# ['40321', '04.10.2016 6:57', '1108', '0,000925926', 'sem', 'yandex', '0,27', '2874', '19,80']
# ['39825', '04.10.2016 10:01', '1140', '0,003287037', 'email', 'promo', '0', '3833', '22,00']
# ['39002', '01.10.2016 16:53', '1141', '0,012986111', 'email', 'promo', '0', '6285', '16,00']
# ['38995', '05.10.2016 3:31', '1145', '0,001643519', 'seo', 'yandex', '0', '4274', '16,00']
# ['40155', '06.10.2016 4:00', '1145', '0,001388889', 'sem', 'yandex', '0,13', '3850', '20,00']
# ['35987', '02.10.2016 8:08', '1149', '0,006493056', 'email', 'promo', '0', '3147', '10,00']
# ['39720', '07.10.2016 16:12', '1149', '0,001388889', 'sem', 'yandex', '0,05', '3135', '21,20']
# ['37876', '08.10.2016 6:55', '1149', '0,012986111', 'seo', 'yandex', '0', '3760', '30,40']
# ['35544', '08.10.2016 22:55', '1149', '0,000462963', 'cpa-partners', 'burgerclub', '1,696', '4166', '18,80']
# ['39798', '09.10.2016 4:10', '1149', '0,001921296', 'sem', 'yandex', '0,01', '3106', '14,00']
# ['38528', '09.10.2016 10:26', '1149', '0,00337963', 'email', 'promo', '0', '3118', '22,00']
# ['38548', '09.10.2016 22:22', '1149', '0,00337963', 'sem', 'google', '0,1', '3528', '16,00']
# ['36070', '07.10.2016 6:57', '1150', '0,001643519', 'sem', 'yandex', '0,19', '6023', '12,60']
# ['36315', '02.10.2016 12:03', '1154', '0,006493056', 'sem', 'google', '0,23', '4216', '13,40']
# ['40052', '04.10.2016 22:51', '1154', '0,000462963', 'seo', 'yandex', '0', '3838', '13,60']
# ['39512', '04.10.2016 9:28', '1159', '0,006493056', 'sem', 'yandex', '0,05', '3863', '10,20']
# ['41741', '04.10.2016 13:34', '1159', '0,000925926', 'brand', 'yandex', '0', '4292', '17,40']
# ['39030', '08.10.2016 9:43', '1164', '0,001643519', 'sem', 'google', '0,18', '6025', '22,40']
# ['38654', '07.10.2016 14:57', '1167', '0,000821759', 'sem', 'yandex', '0,29', '6161', '11,40']
# ['36339', '07.10.2016 20:25', '1175', '0,001643519', 'sem', 'google', '0,12', '6368', '14,00']
# ['37849', '06.10.2016 12:48', '1181', '0,002777778', 'seo', 'yandex', '0', '6280', '22,40']
# ['39223', '07.10.2016 9:54', '1182', '0,003842593', 'sem', 'yandex', '0,26', '6577', '18,00']
# ['36155', '10.10.2016 2:35', '1182', '0,006493056', 'brand', 'direct', '0', '6742', '17,00']
# ['38248', '04.10.2016 13:49', '1193', '0,001921296', 'cpa-partners', 'food-delivery', '2,49', '5215', '24,80']
# ['39420', '09.10.2016 20:49', '1193', '0,000821759', 'brand', 'google', '0', '4511', '16,60']
# ['41371', '01.10.2016 5:12', '1198', '0,000821759', 'sem', 'google', '0,13', '4529', '17,80']
# ['41877', '06.10.2016 7:52', '1198', '0,00337963', 'sem', 'google', '0,13', '5234', '9,00']
# ['37457', '06.10.2016 5:15', '1201', '0,000462963', 'email', 'promo', '0', '6394', '10,60']
# ['36042', '05.10.2016 13:55', '1203', '0,001388889', 'brand', 'google', '0', '5260', '23,40']
# ['41980', '08.10.2016 13:21', '1228', '0,000925926', 'seo', 'google', '0', '5403', '17,60']
# ['38124', '03.10.2016 15:47', '1230', '0,002777778', 'email', 'promo', '0', '7342', '20,60']
# ['36880', '01.10.2016 9:02', '1233', '0,003842593', 'cpa-partners', 'food-delivery', '2,25', '5421', '15,00']
# ['35556', '01.10.2016 10:27', '1233', '0,001643519', 'sem', 'yandex', '0,09', '4826', '22,00']
# ['42255', '02.10.2016 22:01', '1236', '0,000821759', 'email', 'promo', '0', '7278', '17,40']
# ['40501', '05.10.2016 5:27', '1238', '0,001643519', 'seo', 'yandex', '0', '4828', '13,60']
# ['37099', '09.10.2016 14:43', '1238', '0,006759259', 'seo', 'yandex', '0', '5435', '17,60']
# ['40758', '04.10.2016 22:25', '1242', '0,001388889', 'email', 'promo', '0', '6135', '18,40']
# ['39152', '06.10.2016 4:54', '1243', '0,002777778', 'email', 'promo', '0', '5455', '20,40']
# ['40228', '06.10.2016 14:28', '1243', '0,003287037', 'sem', 'yandex', '0,01', '4844', '20,00']
# ['40050', '01.10.2016 4:27', '1246', '0,001643519', 'brand', 'yandex', '0', '3234', '17,80']
# ['38232', '02.10.2016 4:27', '1246', '0,001921296', 'seo', 'google', '0', '1062', '16,00']
# ['37402', '02.10.2016 8:45', '1246', '0,001388889', 'email', 'promo', '0', '1077', '14,60']
# ['41698', '02.10.2016 16:58', '1246', '0,006493056', 'email', 'promo', '0', '1087', '17,20']
# ['38485', '02.10.2016 17:30', '1246', '0,002777778', 'sem', 'yandex', '0,03', '4344', '13,60']
# ['36621', '02.10.2016 19:46', '1246', '0,003842593', 'email', 'promo', '0', '3387', '23,60']
# ['38870', '03.10.2016 2:05', '1246', '0,001643519', 'sem', 'google', '0,02', '1136', '15,60']
# ['35685', '03.10.2016 2:57', '1246', '0,000821759', 'sem', 'yandex', '0,04', '1117', '21,40']
# ['39264', '03.10.2016 7:19', '1246', '0,002777778', 'sem', 'google', '0,03', '1248', '13,00']
# ['38587', '03.10.2016 12:15', '1246', '0,000821759', 'seo', 'yandex', '0', '1115', '18,60']
# ['37291', '03.10.2016 14:58', '1246', '0,000821759', 'cpa-partners', 'burgerclub', '1,648', '3184', '20,60']
# ['36947', '03.10.2016 19:43', '1246', '0,003287037', 'seo', 'yandex', '0', '1306', '11,40']
# ['39535', '04.10.2016 7:27', '1246', '0,001643519', 'email', 'promo', '0', '3884', '18,00']
# ['41495', '04.10.2016 9:08', '1246', '0,000925926', 'smm', 'vk', '0', '1180', '12,00']
# ['36292', '04.10.2016 13:52', '1246', '0,003842593', 'sem', 'yandex', '0,14', '1187', '16,00']
# ['35743', '04.10.2016 16:34', '1246', '0,000462963', 'sem', 'google', '0,05', '1010', '12,20']
# ['40406', '05.10.2016 0:27', '1246', '0,006759259', 'brand', 'direct', '0', '1245', '23,00']
# ['40983', '05.10.2016 6:36', '1246', '0,00337963', 'sem', 'yandex', '0,03', '1075', '24,00']
# ['40289', '05.10.2016 12:59', '1246', '0,001643519', 'email', 'promo', '0', '1265', '11,80']
# ['41849', '05.10.2016 16:52', '1246', '0,000821759', 'email', 'newsletter', '0', '3170', '17,20']
# ['42207', '05.10.2016 17:26', '1246', '0,001643519', 'email', 'newsletter', '0', '1277', '24,60']
# ['37859', '06.10.2016 6:48', '1246', '0,012986111', 'sem', 'yandex', '0,01', '1261', '30,40']
# ['39290', '08.10.2016 2:53', '1246', '0,001388889', 'sem', 'yandex', '0,14', '3553', '18,00']
# ['41132', '10.10.2016 0:59', '1246', '0,000925926', 'email', 'promo', '0', '3299', '15,00']
# ['35440', '01.10.2016 16:30', '1248', '0,012986111', 'sem', 'google', '0,02', '5482', '13,20']
# ['39917', '01.10.2016 21:06', '1248', '0,000462963', 'seo', 'yandex', '0', '4905', '28,80']
# ['40971', '02.10.2016 7:12', '1252', '0,001921296', 'sem', 'yandex', '0,01', '6410', '22,00']
# ['41893', '04.10.2016 13:51', '1252', '0,012986111', 'email', 'promo', '0', '6606', '15,60']
# ['37164', '01.10.2016 12:36', '1253', '0,001921296', 'sem', 'yandex', '0,07', '4938', '13,60']
# ['36692', '04.10.2016 17:11', '1253', '0,001643519', 'sem', 'google', '0,06', '5486', '8,60']
# ['41480', '02.10.2016 16:22', '1258', '0,001643519', 'sem', 'google', '0,4', '5503', '22,00']
# ['36367', '08.10.2016 19:34', '1258', '0,00337963', 'email', 'promo', '0', '4940', '20,00']
# ['36286', '02.10.2016 10:36', '1263', '0,003287037', 'sem', 'yandex', '0,03', '5512', '12,60']
# ['36699', '03.10.2016 6:10', '1263', '0,001388889', 'sem', 'google', '0,04', '4948', '18,00']
# ['35428', '02.10.2016 21:42', '1267', '0,006493056', 'brand', 'direct', '0', '6487', '11,00']
# ['39811', '04.10.2016 9:02', '1267', '0,002777778', 'email', 'promo', '0', '1742', '12,20']
# ['41645', '04.10.2016 12:10', '1267', '0,006493056', 'sem', 'yandex', '0,14', '3562', '18,00']
# ['41591', '04.10.2016 15:40', '1267', '0,000925926', 'email', 'promo', '0', '1628', '12,40']
# ['38127', '04.10.2016 18:37', '1267', '0,006759259', 'seo', 'google', '0', '3388', '13,00']
# ['39609', '04.10.2016 21:29', '1267', '0,012986111', 'brand', 'direct', '0', '4349', '21,40']
# ['39797', '05.10.2016 21:11', '1267', '0,001921296', 'sem', 'yandex', '0,12', '1447', '13,60']
# ['41333', '05.10.2016 22:09', '1267', '0,001643519', 'cpa-partners', 'food-delivery', '1,8', '1561', '17,40']
# ['41194', '06.10.2016 3:58', '1267', '0,000925926', 'sem', 'google', '0,08', '3890', '15,00']
# ['42060', '06.10.2016 11:16', '1267', '0,000462963', 'seo', 'yandex', '0', '1322', '14,40']
# ['37926', '06.10.2016 19:20', '1267', '0,003842593', 'brand', 'direct', '0', '1664', '16,00']
# ['39854', '07.10.2016 10:18', '1267', '0,000821759', 'seo', 'yandex', '0', '1508', '12,00']
# ['40616', '08.10.2016 18:18', '1267', '0,001388889', 'sem', 'yandex', '0,08', '1466', '12,80']
# ['41308', '03.10.2016 2:19', '1332', '0,012986111', 'sem', 'yandex', '0,16', '6939', '19,40']
# ['39974', '04.10.2016 22:01', '1333', '0,001388889', 'sem', 'google', '0,02', '6482', '20,00']
# ['36886', '08.10.2016 3:48', '1334', '0,000462963', 'sem', 'yandex', '0,18', '7531', '16,00']
# ['39114', '03.10.2016 1:32', '1343', '0,00337963', 'sem', 'google', '0,04', '7552', '22,00']
# ['36666', '08.10.2016 4:34', '1350', '0,003287037', 'cpa-partners', 'food-delivery', '3', '7128', '12,80']
# ['35294', '04.10.2016 4:09', '1351', '0,012986111', 'email', 'promo', '0', '7796', '20,00']
# ['37619', '06.10.2016 19:09', '1353', '0,001643519', 'sem', 'yandex', '0,03', '7842', '17,40']
# ['42153', '03.10.2016 1:30', '1354', '0,001643519', 'email', 'promo', '0', '7900', '15,60']
# ['37074', '02.10.2016 23:30', '1355', '0,006493056', 'sem', 'google', '0,1', '7605', '22,00']
# ['41126', '08.10.2016 6:50', '1359', '0,006759259', 'sem', 'google', '0,14', '7760', '14,40']
# ['40456', '02.10.2016 13:33', '1362', '0,000462963', 'sem', 'google', '0,14', '7948', '12,20']
# ['41620', '05.10.2016 21:36', '1363', '0,000821759', 'seo', 'yandex', '0', '7651', '12,20']
# ['37464', '04.10.2016 22:06', '1364', '0,001921296', 'email', 'promo', '0', '7960', '20,00']
# ['41706', '01.10.2016 5:29', '1366', '0,003842593', 'cpa-partners', 'food-delivery', '3,36', '7329', '13,00']
# ['35081', '07.10.2016 9:40', '1367', '0,001388889', 'sem', 'yandex', '0,1', '7984', '22,40']
# ['41985', '04.10.2016 7:31', '1371', '0,003287037', 'sem', 'yandex', '0,25', '7920', '13,60']
# ['37236', '04.10.2016 1:36', '1372', '0,002777778', 'sem', 'google', '0,17', '6865', '30,40']
# ['41859', '07.10.2016 17:25', '1374', '0,001643519', 'sem', 'yandex', '0,04', '7443', '12,40']
# ['39909', '05.10.2016 23:06', '1377', '0,006493056', 'sem', 'yandex', '0,32', '7264', '16,00']
# ['38282', '06.10.2016 14:29', '1380', '0,001921296', 'seo', 'yandex', '0', '7535', '30,40']
# ['35349', '09.10.2016 4:55', '1382', '0,000925926', 'cpc-partners', 'city-magazine', '0,15', '7327', '23,20']
# ['42265', '05.10.2016 21:24', '1383', '0,001921296', 'sem', 'google', '0,02', '7168', '20,00']
# ['35802', '05.10.2016 8:14', '1386', '0,001643519', 'email', 'promo', '0', '7681', '12,60']
# ['35239', '03.10.2016 11:43', '1387', '0,000925926', 'sem', 'google', '0,31', '6805', '14,60']
# ['41725', '01.10.2016 6:21', '1388', '0,000462963', 'cpc-partners', 'city-magazine', '0,2', '7149', '11,80']
# ['37175', '03.10.2016 6:03', '1392', '0,000821759', 'smm', 'facebook', '0', '9899', '20,20']
# ['37938', '06.10.2016 5:34', '1393', '0,00337963', 'sem', 'google', '0,11', '7970', '10,00']
# ['36127', '04.10.2016 23:55', '1394', '0,002777778', 'email', 'promo', '0', '7779', '12,80']
# ['39184', '05.10.2016 5:01', '1397', '0,003842593', 'sem', 'yandex', '0,07', '7747', '20,60']
# ['35554', '05.10.2016 22:54', '1398', '0,001643519', 'seo', 'yandex', '0', '6779', '18,00']
# ['35131', '01.10.2016 17:01', '1424', '0,006759259', 'cpa-partners', 'food-delivery', '1,92', '2121', '13,80']
# ['37708', '03.10.2016 6:50', '1424', '0,002777778', 'seo', 'yandex', '0', '2172', '12,80']
# ['41704', '04.10.2016 5:27', '1424', '0,003842593', 'sem', 'yandex', '0,04', '2120', '17,20']
# ['38916', '04.10.2016 16:14', '1424', '0,002777778', 'sem', 'google', '0,09', '3943', '16,00']
# ['35511', '04.10.2016 18:21', '1424', '0,00337963', 'email', 'promo', '0', '4452', '14,20']
# ['36489', '05.10.2016 23:33', '1424', '0,001643519', 'sem', 'yandex', '0,18', '2182', '19,60']
# ['35839', '06.10.2016 7:27', '1424', '0,001643519', 'seo', 'google', '0', '2180', '22,40']
# ['36573', '07.10.2016 3:01', '1424', '0,000925926', 'email', 'promo', '0', '2105', '14,80']
# ['38443', '07.10.2016 16:08', '1424', '0,001643519', 'sem', 'google', '0,14', '3634', '13,00']
# ['41634', '07.10.2016 16:12', '1424', '0,001643519', 'sem', 'google', '0,06', '3422', '13,60']
# ['40614', '08.10.2016 12:41', '1424', '0,001643519', 'email', 'promo', '0', '2090', '12,60']
# ['39592', '08.10.2016 15:26', '1424', '0,012986111', 'seo', 'yandex', '0', '2177', '19,20']
# ['35180', '08.10.2016 17:21', '1424', '0,003287037', 'email', 'promo', '0', '4401', '20,20']
# ['36550', '09.10.2016 8:00', '1424', '0,000821759', 'sem', 'google', '0,19', '2073', '16,00']
# ['39244', '10.10.2016 1:24', '1424', '0,000821759', 'sem', 'yandex', '0,03', '6507', '11,60']

# %%
Started = True

with open( 'data.txt', 'r' ) as f:

    for line in f:        

        if Started:

            Started = False        

        else:

            line = line.strip().split('\t')            

            medium = line[4]

            source = line[5]            

            amount = float( line[-1].replace(',', '.') )

            print( source, medium, amount )
# Out:
# google seo 20.2
# yandex sem 15.6
# promo email 13.2
# yandex sem 9.8
# google sem 14.8
# google sem 14.4
# google sem 14.0
# yandex brand 20.0
# yandex sem 16.2
# promo email 11.0
# burgerclub cpa-partners 10.8
# google seo 22.6
# google seo 22.4
# yandex sem 24.4
# google seo 16.6
# yandex sem 8.6
# yandex seo 12.4
# food-delivery cpa-partners 16.2
# promo email 24.0
# yandex sem 18.8
# promo email 11.8
# google sem 9.4
# google sem 11.2
# promo email 19.0
# google sem 23.4
# city-magazine cpc-partners 17.0
# google seo 20.8
# promo email 15.6
# foody cpc-partners 22.4
# yandex seo 15.6
# food-delivery cpa-partners 21.0
# google seo 22.4
# google sem 20.4
# promo email 26.0
# yandex seo 18.4
# promo email 14.6
# yandex seo 29.8
# promo email 20.0
# google sem 19.0
# google brand 16.4
# yandex sem 16.2
# yandex sem 17.8
# promo email 18.8
# burgerclub cpa-partners 20.0
# google seo 21.0
# yandex seo 16.6
# promo email 20.0
# yandex sem 19.8
# promo email 16.8
# food-delivery cpa-partners 24.0
# yandex sem 12.0
# yandex sem 10.2
# promo email 24.0
# yandex sem 15.8
# yandex sem 22.0
# google sem 17.4
# yandex sem 14.8
# promo email 20.0
# yandex brand 11.6
# yandex seo 20.0
# yandex sem 16.0
# yandex seo 11.2
# google seo 12.2
# yandex sem 19.2
# google sem 17.8
# google sem 19.8
# promo email 8.6
# promo email 28.6
# newsletter email 18.8
# google sem 17.6
# promo email 16.0
# food-delivery cpa-partners 15.4
# yandex sem 21.6
# promo email 7.6
# yandex brand 21.6
# facebook smm 17.4
# google sem 22.0
# promo email 22.0
# promo email 16.0
# yandex seo 16.0
# yandex sem 20.0
# promo email 10.0
# yandex sem 21.2
# yandex seo 30.4
# burgerclub cpa-partners 18.8
# yandex sem 14.0
# promo email 22.0
# google sem 16.0
# yandex sem 12.6
# google sem 13.4
# yandex seo 13.6
# yandex sem 10.2
# yandex brand 17.4
# google sem 22.4
# yandex sem 11.4
# google sem 14.0
# yandex seo 22.4
# yandex sem 18.0
# direct brand 17.0
# food-delivery cpa-partners 24.8
# google brand 16.6
# google sem 17.8
# google sem 9.0
# promo email 10.6
# google brand 23.4
# burgerclub cpa-partners 21.0
# promo email 16.6
# foody cpc-partners 24.2
# google seo 20.4
# yandex seo 25.6
# yandex brand 19.8
# facebook smm 16.4
# promo email 16.2
# yandex seo 17.0
# promo email 16.8
# yandex sem 19.8
# yandex seo 15.6
# newsletter email 19.2
# google sem 23.2
# yandex sem 10.8
# google sem 24.4
# yandex sem 13.4
# yandex seo 12.0
# facebook smm 18.6
# google sem 16.6
# burgerclub cpa-partners 12.2
# burgerclub cpa-partners 22.4
# google seo 15.4
# city-magazine cpc-partners 17.2
# burgerclub cpa-partners 17.6
# promo email 16.4
# promo email 18.6
# promo email 19.8
# google brand 18.8
# google seo 17.6
# promo email 20.6
# food-delivery cpa-partners 15.0
# yandex sem 22.0
# promo email 17.4
# yandex seo 13.6
# yandex seo 17.6
# promo email 18.4
# promo email 20.4
# yandex sem 20.0
# yandex brand 17.8
# google seo 16.0
# promo email 14.6
# promo email 17.2
# yandex sem 13.6
# promo email 23.6
# google sem 15.6
# yandex sem 21.4
# google sem 13.0
# yandex seo 18.6
# burgerclub cpa-partners 20.6
# yandex seo 11.4
# promo email 18.0
# vk smm 12.0
# yandex sem 16.0
# google sem 12.2
# direct brand 23.0
# yandex sem 24.0
# promo email 11.8
# newsletter email 17.2
# newsletter email 24.6
# yandex sem 30.4
# yandex sem 18.0
# promo email 15.0
# google sem 13.2
# yandex seo 28.8
# yandex sem 22.0
# promo email 15.6
# yandex sem 13.6
# google sem 8.6
# google sem 22.0
# promo email 20.0
# yandex sem 12.6
# google sem 18.0
# direct brand 11.0
# promo email 12.2
# yandex sem 18.0
# promo email 12.4
# google seo 13.0
# direct brand 21.4
# yandex sem 13.6
# food-delivery cpa-partners 17.4
# google sem 15.0
# yandex seo 14.4
# direct brand 16.0
# yandex seo 12.0
# yandex sem 12.8
# promo email 21.4
# yandex sem 17.4
# yandex sem 21.6
# promo email 16.0
# google sem 16.4
# yandex sem 16.0
# promo email 22.0
# yandex brand 21.8
# promo email 14.6
# yandex seo 22.0
# promo email 25.0
# google sem 15.6
# promo email 17.8
# yandex sem 14.8
# yandex sem 18.2
# google sem 12.6
# promo email 11.8
# yandex sem 16.0
# yandex seo 30.4
# google seo 13.4
# newsletter email 18.4
# promo email 20.0
# vk smm 17.0
# google sem 26.0
# google sem 21.0
# foody cpc-partners 19.4
# yandex sem 16.0
# yandex sem 12.8
# google sem 14.0
# burgerclub cpa-partners 21.8
# city-magazine cpc-partners 11.8
# google sem 25.8
# google sem 18.0
# google sem 10.2
# promo email 12.0
# google sem 13.8
# google sem 16.6
# google sem 11.4
# google brand 13.4
# yandex sem 14.0
# google sem 16.6
# promo email 24.0
# promo email 10.2
# promo email 18.6
# yandex sem 21.6
# burgerclub cpa-partners 20.2
# yandex sem 18.0
# promo email 17.4
# promo email 22.0
# yandex sem 17.4
# yandex sem 19.0
# facebook smm 18.0
# google brand 16.0
# promo email 28.6
# yandex sem 18.4
# promo email 18.8
# yandex seo 17.8
# yandex sem 16.8
# yandex sem 19.4
# google sem 20.0
# yandex sem 16.0
# google sem 22.0
# food-delivery cpa-partners 12.8
# promo email 20.0
# yandex sem 17.4
# promo email 15.6
# google sem 22.0
# google sem 14.4
# google sem 12.2
# yandex seo 12.2
# promo email 20.0
# food-delivery cpa-partners 13.0
# yandex sem 22.4
# yandex sem 13.6
# google sem 30.4
# yandex sem 12.4
# yandex sem 16.0
# yandex seo 30.4
# city-magazine cpc-partners 23.2
# google sem 20.0
# promo email 12.6
# google sem 14.6
# city-magazine cpc-partners 11.8
# facebook smm 20.2
# google sem 10.0
# promo email 12.8
# yandex sem 20.6
# yandex seo 18.0
# food-delivery cpa-partners 13.8
# yandex seo 12.8
# yandex sem 17.2
# google sem 16.0
# promo email 14.2
# yandex sem 19.6
# google seo 22.4
# promo email 14.8
# google sem 13.0
# google sem 13.6
# promo email 12.6
# yandex seo 19.2
# promo email 20.2
# google sem 16.0
# yandex sem 11.6

# %%
Started = True

total_amount = 0

with open( 'data.txt', 'r' ) as f:

    for line in f:

        if Started:

            Started = False

        else:

            line = line.strip().split('\t')

            medium = line[4]

            source = line[5]

            amount = float( line[-1].replace(',', '.') )

            if source == allowedSource and medium in allowedMedium:

                total_amount += amount

# %%
total_amount
# Out:
# 685.8000000000001

# %%
with open( 'data_no_header.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        current_user_id = line[2]

        print( current_user_id )
# Out:
# 1010
# 1036
# 1041
# 1041
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1047
# 1047
# 1052
# 1052
# 1057
# 1057
# 1062
# 1067
# 1078
# 1085
# 1096
# 1098
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1105
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1111
# 1112
# 1112
# 1113
# 1113
# 1114
# 1114
# 1116
# 1118
# 1118
# 1123
# 1123
# 1128
# 1134
# 1134
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1136
# 1136
# 1140
# 1140
# 1141
# 1145
# 1145
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 
txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        # ID пользователя на текущей строке

        current_user_id = line[2]

        if Started:

            Started = False

            # при обработке первой строки присваиваем "прошлому" ID пользователя первое значение

            previous_user_id = current_user_id

        else:

            if previous_user_id != current_user_id:

                unique_user_ids += 1

        previous_user_id = current_user_id

unique_user_ids += 1

# %%
unique_user_ids
# Out:
# 124

# %%
total_costs = { 'google': 1319, 'yandex': 1818, 'promo': 1181 }

# %%
total_costs['google'] + total_costs['promo']
# Out:
# 2500

# %%
source = 'brand'

if source in total_costs:

    print( 'Расходы на источник {} составили {} рублей'.format( source, total_costs['google'] ) )

else:

    print( 'Источник {} не найден в итоговой статистике'.format( source ) )
# Out:
# Источник brand не найден в итоговой статистике

# %%
for value in total_costs.values():

    print( value )
# Out:
# 1319
# 1818
# 1181

# %%
for key, value in total_costs.items():

    print( key, value )
# Out:
# google 1319
# yandex 1818
# promo 1181

# %%
campaign_stats = {

    'google': { 'cost': 1000, 'clicks': 500 },

    'yandex': { 'cost': 1500, 'clicks': 900 }

}

# %%
for campaign, stats in campaign_stats.items():

    print( 'Кампания {}, цена клика {:.2f} USD'.format( campaign, stats['cost'] / stats['clicks'] ) )
# Out:
# Кампания google, цена клика 2.00 USD
# Кампания yandex, цена клика 1.67 USD

# %%
users_stats_dict = {}

with open( 'data_no_header.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        current_user_id = line[2]

# %%
users_stats_dict = {}

i = 0

with open( 'data_no_header.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        current_user_id = line[2]

        # если ID пользователя уже есть в нашем словаре, то добавляем ему +1

        if current_user_id in users_stats_dict:

            users_stats_dict[ current_user_id ] += 1

        # если ID пользователя еще нет в словаре, то создаем для него ключ со значением 1

        else:

            users_stats_dict[ current_user_id ] = 1

        

        print( 'Текущий ID: {}'.format( current_user_id ) )

        print( users_stats_dict )

        print( '' )

        

        # если прошли более 5 шагов, то выходим из цикла (команда break)

        i += 1
# Out:
# Текущий ID: 1010
# {'1010': 1}
#
# Текущий ID: 1036
# {'1010': 1, '1036': 1}
#
# Текущий ID: 1041
# {'1010': 1, '1036': 1, '1041': 1}
#
# Текущий ID: 1041
# {'1010': 1, '1036': 1, '1041': 2}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 1}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 2}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 3}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 4}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 5}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 6}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 7}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 8}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 9}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 10}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 11}
#
# Текущий ID: 1042
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12}
#
# Текущий ID: 1047
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 1}
#
# Текущий ID: 1047
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2}
#
# Текущий ID: 1052
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 1}
#
# Текущий ID: 1052
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2}
#
# Текущий ID: 1057
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 1}
#
# Текущий ID: 1057
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2}
#
# Текущий ID: 1062
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1}
#
# Текущий ID: 1067
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1}
#
# Текущий ID: 1078
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1}
#
# Текущий ID: 1085
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1}
#
# Текущий ID: 1096
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1}
#
# Текущий ID: 1098
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1}
#
# Текущий ID: 1100
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 1}
#
# Текущий ID: 1100
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 2}
#
# Текущий ID: 1100
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 3}
#
# Текущий ID: 1100
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 4}
#
# Текущий ID: 1100
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 5}
#
# Текущий ID: 1100
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 6}
#
# Текущий ID: 1100
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 7}
#
# Текущий ID: 1100
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 8}
#
# Текущий ID: 1100
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 9}
#
# Текущий ID: 1100
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 10}
#
# Текущий ID: 1100
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 11}
#
# Текущий ID: 1100
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12}
#
# Текущий ID: 1105
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1}
#
# Текущий ID: 1108
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 1}
#
# Текущий ID: 1108
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 2}
#
# Текущий ID: 1108
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 3}
#
# Текущий ID: 1108
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 4}
#
# Текущий ID: 1108
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 5}
#
# Текущий ID: 1108
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 6}
#
# Текущий ID: 1108
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 7}
#
# Текущий ID: 1108
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 8}
#
# Текущий ID: 1108
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9}
#
# Текущий ID: 1111
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1}
#
# Текущий ID: 1112
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 1}
#
# Текущий ID: 1112
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2}
#
# Текущий ID: 1113
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 1}
#
# Текущий ID: 1113
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2}
#
# Текущий ID: 1114
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 1}
#
# Текущий ID: 1114
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2}
#
# Текущий ID: 1116
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1}
#
# Текущий ID: 1118
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 1}
#
# Текущий ID: 1118
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2}
#
# Текущий ID: 1123
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 1}
#
# Текущий ID: 1123
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2}
#
# Текущий ID: 1128
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1}
#
# Текущий ID: 1134
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 1}
#
# Текущий ID: 1134
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2}
#
# Текущий ID: 1135
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 1}
#
# Текущий ID: 1135
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 2}
#
# Текущий ID: 1135
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 3}
#
# Текущий ID: 1135
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 4}
#
# Текущий ID: 1135
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 5}
#
# Текущий ID: 1135
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 6}
#
# Текущий ID: 1135
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 7}
#
# Текущий ID: 1135
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 8}
#
# Текущий ID: 1135
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9}
#
# Текущий ID: 1136
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 1}
#
# Текущий ID: 1136
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2}
#
# Текущий ID: 1140
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 1}
#
# Текущий ID: 1140
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2}
#
# Текущий ID: 1141
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1}
#
# Текущий ID: 1145
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 1}
#
# Текущий ID: 1145
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2}
#
# Текущий ID: 1149
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 1}
#
# Текущий ID: 1149
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 2}
#
# Текущий ID: 1149
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 3}
#
# Текущий ID: 1149
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 4}
#
# Текущий ID: 1149
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 5}
#
# Текущий ID: 1149
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 6}
#
# Текущий ID: 1149
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7}
#
# Текущий ID: 1150
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1}
#
# Текущий ID: 1154
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 1}
#
# Текущий ID: 1154
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2}
#
# Текущий ID: 1159
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 1}
#
# Текущий ID: 1159
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2}
#
# Текущий ID: 1164
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1}
#
# Текущий ID: 1167
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1}
#
# Текущий ID: 1175
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1}
#
# Текущий ID: 1181
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1}
#
# Текущий ID: 1182
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 1}
#
# Текущий ID: 1182
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2}
#
# Текущий ID: 1193
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 1}
#
# Текущий ID: 1193
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2}
#
# Текущий ID: 1198
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 1}
#
# Текущий ID: 1198
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2}
#
# Текущий ID: 1201
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1}
#
# Текущий ID: 1203
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 1}
#
# Текущий ID: 1203
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 1}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 2}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 3}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 4}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 5}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 6}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 7}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 8}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 9}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 10}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 11}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 12}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 13}
#
# Текущий ID: 1207
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14}
#
# Текущий ID: 1208
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 1}
#
# Текущий ID: 1208
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2}
#
# Текущий ID: 1209
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1}
#
# Текущий ID: 1213
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 1}
#
# Текущий ID: 1213
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2}
#
# Текущий ID: 1218
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 1}
#
# Текущий ID: 1218
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2}
#
# Текущий ID: 1219
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1}
#
# Текущий ID: 1223
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 1}
#
# Текущий ID: 1223
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2}
#
# Текущий ID: 1224
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1}
#
# Текущий ID: 1226
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 1}
#
# Текущий ID: 1226
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2}
#
# Текущий ID: 1228
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 1}
#
# Текущий ID: 1228
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2}
#
# Текущий ID: 1230
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1}
#
# Текущий ID: 1233
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1, '1233': 1}
#
# Текущий ID: 1233
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1, '1233': 2}
#
# Текущий ID: 1236
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1, '1233': 2, '1236': 1}
#
# Текущий ID: 1238
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1, '1233': 2, '1236': 1, '1238': 1}
#
# Текущий ID: 1238
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1, '1233': 2, '1236': 1, '1238': 2}
#
# Текущий ID: 1242
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1, '1233': 2, '1236': 1, '1238': 2, '1242': 1}
#
# Текущий ID: 1243
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1, '1233': 2, '1236': 1, '1238': 2, '1242': 1, '1243': 1}
#
# Текущий ID: 1243
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1, '1233': 2, '1236': 1, '1238': 2, '1242': 1, '1243': 2}
#
# Текущий ID: 1246
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1, '1233': 2, '1236': 1, '1238': 2, '1242': 1, '1243': 2, '1246': 1}
#
# Текущий ID: 1246
# ...
#
# Текущий ID: 1424
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1, '1233': 2, '1236': 1, '1238': 2, '1242': 1, '1243': 2, '1246': 24, '1248': 2, '1252': 2, '1253': 2, '1258': 2, '1263': 2, '1267': 17, '1268': 2, '1269': 1, '1270': 1, '1273': 2, '1274': 1, '1278': 2, '1279': 1, '1281': 1, '1283': 2, '1288': 2, '1291': 1, '1293': 2, '1294': 1, '1296': 1, '1298': 3, '1300': 2, '1302': 1, '1303': 2, '1308': 2, '1313': 2, '1315': 1, '1318': 14, '1320': 1, '1323': 2, '1328': 2, '1330': 1, '1331': 1, '1332': 1, '1333': 1, '1334': 1, '1343': 1, '1350': 1, '1351': 1, '1353': 1, '1354': 1, '1355': 1, '1359': 1, '1362': 1, '1363': 1, '1364': 1, '1366': 1, '1367': 1, '1371': 1, '1372': 1, '1374': 1, '1377': 1, '1380': 1, '1382': 1, '1383': 1, '1386': 1, '1387': 1, '1388': 1, '1392': 1, '1393': 1, '1394': 1, '1397': 1, '1398': 1, '1424': 5}
#
# Текущий ID: 1424
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1, '1233': 2, '1236': 1, '1238': 2, '1242': 1, '1243': 2, '1246': 24, '1248': 2, '1252': 2, '1253': 2, '1258': 2, '1263': 2, '1267': 17, '1268': 2, '1269': 1, '1270': 1, '1273': 2, '1274': 1, '1278': 2, '1279': 1, '1281': 1, '1283': 2, '1288': 2, '1291': 1, '1293': 2, '1294': 1, '1296': 1, '1298': 3, '1300': 2, '1302': 1, '1303': 2, '1308': 2, '1313': 2, '1315': 1, '1318': 14, '1320': 1, '1323': 2, '1328': 2, '1330': 1, '1331': 1, '1332': 1, '1333': 1, '1334': 1, '1343': 1, '1350': 1, '1351': 1, '1353': 1, '1354': 1, '1355': 1, '1359': 1, '1362': 1, '1363': 1, '1364': 1, '1366': 1, '1367': 1, '1371': 1, '1372': 1, '1374': 1, '1377': 1, '1380': 1, '1382': 1, '1383': 1, '1386': 1, '1387': 1, '1388': 1, '1392': 1, '1393': 1, '1394': 1, '1397': 1, '1398': 1, '1424': 6}
#
# Текущий ID: 1424
# {'1010': 1, '1036': 1, '1041': 2, '1042': 12, '1047': 2, '1052': 2, '1057': 2, '1062': 1, '1067': 1, '1078': 1, '1085': 1, '1096': 1, '1098': 1, '1100': 12, '1105': 1, '1108': 9, '1111': 1, '1112': 2, '1113': 2, '1114': 2, '1116': 1, '1118': 2, '1123': 2, '1128': 1, '1134': 2, '1135': 9, '1136': 2, '1140': 2, '1141': 1, '1145': 2, '1149': 7, '1150': 1, '1154': 2, '1159': 2, '1164': 1, '1167': 1, '1175': 1, '1181': 1, '1182': 2, '1193': 2, '1198': 2, '1201': 1, '1203': 2, '1207': 14, '1208': 2, '1209': 1, '1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1, '1233': 2, '1236': 1, '1238': 2, '1242': 1, '1243': 2, '1246':
'1213': 2, '1218': 2, '1219': 1, '1223': 2, '1224': 1, '1226': 2, '1228': 2, '1230': 1, '1233': 2, '1236': 1, '1238': 2, '1242': 1, '1243': 2, '1246': 24, '1248': 2, '1252': 2, '1253': 2, '1258': 2, '1263': 2, '1267': 17, '1268': 2, '1269': 1, '1270': 1, '1273': 2, '1274': 1, '1278': 2, '1279': 1, '1281': 1, '1283': 2, '1288': 2, '1291': 1, '1293': 2, '1294': 1, '1296': 1, '1298': 3, '1300': 2, '1302': 1, '1303': 2, '1308': 2, '1313': 2, '1315': 1, '1318': 14, '1320': 1, '1323': 2, '1328': 2, '1330': 1, '1331': 1, '1332': 1, '1333': 1, '1334': 1, '1343': 1, '1350': 1, '1351': 1, '1353': 1, '1354': 1, '1355': 1, '1359': 1, '1362': 1, '1363': 1, '1364': 1, '1366': 1, '1367': 1, '1371': 1, '1372': 1, '1374': 1, '1377': 1, '1380': 1, '1382': 1, '1383': 1, '1386': 1, '1387': 1, '1388': 1, '1392': 1, '1393': 1, '1394': 1, '1397': 1, '1398': 1, '1424': 15}

# %%
with open( 'data_no_header.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        source = line[5]

        medium = line[4]

        if source == 'google' or source == 'yandex':

            if medium == 'seo' or medium == 'sem':

                sourceType = 'search engines seo'

            elif medium == 'brand':

                sourceType = 'search engines brand'

            else:

                # если вдруг встретится другой вариант, то ставим "undefined"

                sourceType = 'search engines undefined'

        else:

            sourceType = 'other'

        # код с формированием словаря статистики

# %%
sourceType
# Out:
# 'search engines seo'

# %%
def source_type_classification( source, medium ):

    """

    Функция классифицирует источник трафика в зависимости от значения source и medium.

    Возвращает название типа источника по правилам:

        - если source равен 'google' или 'yandex', то проверяем medium:

            - для medium 'seo' или 'sem' возвращаем 'search engines seo'

            - для medium 'brand' - возвращаем 'search engines brand'

            - для остальных случаев возвращаем 'search engines undefined'

        - если условие не выполнено, то возвращаем 'other'

    """

    if source == 'google' or source == 'yandex':

        if medium == 'seo' or medium == 'sem':

            return 'search engines seo'

        elif medium == 'brand':

            return 'search engines brand'

        else:

            # если вдруг встретится другой вариант, то ставим "undefined"

            return 'search engines undefined'

    else:

        return 'other'

# %%
source_type_classification( 'google', 'seo' )
# Out:
# 'search engines seo'

# %%
print( source_type_classification( 'yandex', 'seo' ) ) # должны получить 'search engines seo'
# Out:
# search engines seo

# %%
print( source_type_classification( 'google', 'brand' ) ) # должны получить 'search engines brand'
# Out:
# search engines brand

# %%
print( source_type_classification( 'google', '123' ) ) # должны получить 'search engines brand'
# Out:
# search engines undefined

# %%
with open( 'data_no_header.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        source = line[5]

        medium = line[4]

        sourceType = source_type_classification( source, medium )

        # код с формированием словаря статистики

# %%
source_type_stats = {}

with open( 'data_no_header.txt', 'r' ) as f:

    for line in f:       

        line = line.strip().split('\t')

        source = line[5]

        medium = line[4]

        sourceType = source_type_classification( source, medium )

        if sourceType in source_type_stats:

            source_type_stats[ sourceType ] += 1

        else:

            source_type_stats[ sourceType ] = 1

# %%
source_type_stats
# Out:
# {'search engines seo': 168, 'other': 113, 'search engines brand': 13}

# %%
def source_type_classification( line ):

    """

    Пример строки на входе функции:

    ['40443', '05.10.2016 23:18', '1010', '0,000925926', 'seo', 'google', '0', '6243', '20,20']

    Функция классифицирует источник трафика в зависимости от значения source и medium.

    Возвращает название типа источника по правилам:

        - если source равен 'google' или 'yandex', то проверяем medium:

            - для medium 'seo' или 'sem' возвращаем 'search engines seo'

            - для medium 'brand' - возвращаем 'search engines brand'

            - для остальных случаев возвращаем 'search engines undefined'

        - если условие не выполнено, то возвращаем 'other'

    """

    source = line[5]

    medium = line[4]

    if source == 'google' or source == 'yandex':

        if medium == 'seo' or medium == 'sem':

            return 'search engines seo'

        elif medium == 'brand':

            return 'search engines brand'

        else:

            # если вдруг встретится другой вариант, то ставим "undefined"

            return 'search engines undefined'

    else:

        return 'other'

# %%
source_type_classification(['40443', '05.10.2016 23:18', '1010', '0,000925926', 'seo', 'google', '0', '6243', '20,20'])
# Out:
# 'search engines seo'

# %%
def source_type_classification( line ):

    source = line[5]

    medium = line[4]

    amount_paid = float( line[-1].replace(',', '.') )

    if amount_paid >= 20:

        orderType = 'expensive'

    else:

        orderType = 'cheap'

    if source == 'google' or source == 'yandex':

        if medium == 'seo' or medium == 'sem':

            sourceType = 'search engines seo'

        elif medium == 'brand':

            sourceType = 'search engines brand'

        else:

            # если вдруг встретится другой вариант, то ставим "undefined"

            sourceType = 'search engines undefined'

    else:

        sourceType = 'other'

    return sourceType, orderType

#В итоге для подсчета количества заказов в разбивке по типам трафика и стоимости заказа нам потребуется следующий цикл:

source_type_stats = {}

with open( 'data_no_header.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        sourceType, orderType = source_type_classification( line )

        source_order_type = sourceType + ' ' + orderType

        if source_order_type in source_type_stats:

            source_type_stats[ source_order_type ] += 1

        else:

            source_type_stats[ source_order_type ] = 1

# %%
source_type_stats['search engines seo cheap']
# Out:
# 121

# %%
cpa_commission = {

    'burgerclub': 0.3,

    'food-delivery': 0.25

}

cpc_commission = {

    'city-magazine': 7,

    'foody': 9

}

# %%
fixed_commission = 4

# %%
def costs_classification( amount_paid, source ):

    """

    Функция по названию канала source возвращает размер комиссии.

    Размеры комиссий берутся из словарей cpa_commission, cpc_commission и значения fixed_commission

    """

    # если источник source входит в словарь cpa_commission, то возвращаем долю от выручки

    if source in cpa_commission:

        return amount_paid * cpa_commission[ source ]

    # в случае партнеров CPC стоимость расходов постоянная

    if source in cpc_commission:

        return cpc_commission[ source ]

    # если ни один случай не подходит, то возвращаем фиксированную стоимость fixed_commission

    return fixed_commission

# %%
costs_classification( 10, 'burgerclub' ) # 30% от 10 рублей
# Out:
# 3.0

# %%
costs_classification( 10, 'foody' ) # фиксированная сумма в 9 рублей
# Out:
# 9

# %%
costs_classification( 10, 'google' ) # фиксированная сумма в 9 рублей
# Out:
# 4

# %%
line = ['40443', '05.10.2016 23:18', '1010', '0,000925926', 'seo', 'google', '0', '6243', '20,20']

# %%
def expense_and_income( line ):

    """

    Функция для строки line возвращает итоговый расход и доход

    """

    source = line[5]

    amount_paid = float( line[-1].replace( ',', '.' ) )

    cost = float( line[6].replace( ',', '.' ) )

    return source, cost, amount_paid

# %%
expense_and_income( line )
# Out:
# ('google', 0.0, 20.2)

# %%
def expense_and_income( line ):

    """

    Функция для строки line возвращает итоговый расход и доход

    """

    source = line[5]

    amount_paid = float( line[-1].replace( ',', '.' ) )

    cost = float( line[6].replace( ',', '.' ) )

    partner_comission = costs_classification( amount_paid, source )

    return source, cost, amount_paid, partner_comission

# %%
expense_and_income(line)
# Out:
# ('google', 0.0, 20.2, 4)

# %%
def expense_and_income( line ):

    """

    Функция для строки line возвращает итоговый расход и доход

    """

    source = line[5]

    amount_paid = float( line[-1].replace( ',', '.' ) )

    cost = float( line[6].replace( ',', '.' ) )

    partner_comission = costs_classification( amount_paid, source )

    return source, cost + partner_comission, amount_paid

# %%
# должны получить расходы 20.2 * 0.3 + 1 = 7.06

expense_and_income( ['40443', '05.10.2016 23:18', '1010', '0,000925926', 'seo', 'burgerclub', '1', '6243', '20,20'] )
# Out:
# ('burgerclub', 7.06, 20.2)

# %%
roi_stats = {}

with open( 'data_no_header.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        source, cost, income = expense_and_income( line )

        if source in roi_stats:

            roi_stats[ source ][ 'cost' ] += cost

            roi_stats[ source ][ 'income' ] += income

        else:

            roi_stats[ source ] = {}

            roi_stats[ source ][ 'cost' ] = cost

            roi_stats[ source ][ 'income' ] = income

# %%
for source, data in roi_stats.items():

    data['roi'] = ( data['income'] - data['cost'] ) / data['cost']

# %%
for source, data in roi_stats.items():

    print( '{}\t{:.2f}'.format( source, data['roi'] ) )
# Out:
# google	3.19
# yandex	3.29
# promo	3.34
# burgerclub	1.64
# food-delivery	1.56
# city-magazine	1.26
# foody	1.42
# newsletter	3.91
# facebook	3.53
# direct	3.42
# vk	2.62

# %%
def source_type_classification( line ):

    source = line[5]

    medium = line[4]

    amount_paid = float( line[-1].replace(',', '.') )

    if amount_paid >= 20:

        orderType = 'expensive'

    else:

        orderType = 'cheap'

    if source == 'google' or source == 'yandex':

        if medium == 'seo' or medium == 'sem':

            sourceType = 'search engines seo'

        elif medium == 'brand':

            sourceType = 'search engines brand'

        else:

            # если вдруг встретится другой вариант, то ставим "undefined"

            sourceType = 'search engines undefined'

    else:

        sourceType = 'other'

    return sourceType, orderType

# %%
def expense_and_income( line ):

    """

    Функция для строки line возвращает итоговый расход и доход

    """

    source = line[5]

    amount_paid = float( line[-1].replace( ',', '.' ) )

    cost = float( line[6].replace( ',', '.' ) )

    partner_comission = costs_classification( amount_paid, source )

    return source, cost + partner_comission, amount_paid

# %%
roi_stats = {}

with open( 'data_no_header.txt', 'r' ) as f:

    for line in f:

        line = line.strip().split('\t')

        source, cost, income = expense_and_income( line )

        if source in roi_stats:

            roi_stats[ source ][ 'cost' ] += cost

            roi_stats[ source ][ 'income' ] += income

        else:

            roi_stats[ source ] = {}

            roi_stats[ source ][ 'cost' ] = cost

            roi_stats[ source ][ 'income' ] = income
            
for source, data in roi_stats.items():

    data['roi'] = ( data['income'] - data['cost'] ) / data['cost']
