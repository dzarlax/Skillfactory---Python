# %%
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('power.csv')

# %%
data.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
data.tail(10)
# Out:
#           country  year  quantity  category
# 1189472   Vanuatu  2010      5.17        71
# 1189473   Vanuatu  2009      5.63        71
# 1189474   Vanuatu  2008      5.63        71
# 1189475  Viet Nam  2014    300.00        71
# 1189476  Viet Nam  2013     92.00        71
# 1189477  Viet Nam  2012     92.00        71
# 1189478  Viet Nam  2011     87.00        71
# 1189479  Viet Nam  2010     50.00        71
# 1189480  Viet Nam  2009     10.00        71
# 1189481  Viet Nam  2008      1.00        71

# %%
data2 = pd.read_csv('transactions-2.csv', sep=';')

# %%
data2.head()
# Out:
#      Year  Month    ID Product  Amount   Price    Total    Cost
# 0  2012.0    1.0  t001      A1     7.0  2904.0  20328.0  1200.0
# 1  2012.0    1.0  t002      A2     2.0  1896.0   3792.0  1100.0
# 2  2012.0    2.0  t003      A1     5.0  2904.0  14520.0  1200.0
# 3  2012.0    2.0  t004      A4     1.0  8618.0   8618.0  4200.0
# 4  2012.0    2.0  t005      A5     3.0  5175.0  15525.0   500.0

# %%
len(data)
# Out:
# 1189482

# %%
data3 = pd.read_csv('transactions_data.csv')
data3.head()
# Out:
#    Year  Month    ID Product  Amount  Price  Total  Cost
# 0  2017      1  t001      A1       7   2904  20328  1200
# 1  2017      1  t002      A2       2   1896   3792  1100
# 2  2017      2  t003      A1       5   2904  14520  1200
# 3  2017      2  t004      A4       1   8618   8618  4200
# 4  2017      2  t005      A5       3   5175  15525   500

# %%
len(data3)
# Out:
# 60

# %%
data.shape
# Out:
# (1189482, 4)

# %%
len(data['country'].unique())
# Out:
# 243

# %%
data['country'].value_counts()
# Out:
# Germany                                     20422
# United States                               19847
# Poland                                      19802
# Austria                                     17440
# Romania                                     17357
# France                                      17236
# Japan                                       17037
# Czechia                                     16588
# Italy                                       16312
# Netherlands                                 15955
# Spain                                       15815
# Hungary                                     15778
# Australia                                   15652
# United Kingdom                              15536
# Canada                                      15453
# Russian Federation                          15020
# Finland                                     14982
# Belgium                                     14914
# Korea, Republic of                          14849
# ...

# %%
data2['Product'].value_counts()
# Out:
# _5    11
# _2     8
# _8     8
# _4     7
# _3     7
# A4     5
# A5     5
# A1     5
# _6     2
# A2     2
# Name: Product, dtype: int64

# %%
data['quantity'].mean()
# Out:
# 184264.77005012965

# %%
data.describe()
# Out:
#                year      quantity      category
# count  1.189482e+06  1.189482e+06  1.189482e+06
# mean   2.002852e+03  1.842648e+05  3.624763e+01
# std    7.167345e+00  1.585663e+07  1.809968e+01
# min    1.990000e+03 -8.643480e+05  1.000000e+00
# 25%    1.997000e+03  1.400000e+01  2.400000e+01
# 50%    2.003000e+03  1.890000e+02  3.500000e+01
# 75%    2.009000e+03  2.265000e+03  5.100000e+01
# max    2.014000e+03  6.680329e+09  7.100000e+01

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1189482 entries, 0 to 1189481
# Data columns (total 4 columns):
# country     1189482 non-null object
# year        1189482 non-null int64
# quantity    1189482 non-null float64
# category    1189482 non-null int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 36.3+ MB

# %%
country_stats = data.filter(items = ['country', 'quantity'])

# %%
country_stats
# Out:
#                country  quantity
# 0              Austria      5.00
# 1              Austria     17.00
# 2              Belgium      0.00
# 3              Belgium      0.00
# 4              Belgium     35.00
# 5              Belgium     25.00
# 6              Belgium     22.00
# 7              Belgium     45.00
# 8              Czechia      1.00
# 9              Czechia      7.00
# 10             Finland      9.00
# 11             Finland     13.00
# 12             Finland     39.00
# 13             Finland     21.00
# 14             Finland      0.00
# 15             Finland      0.00
# 16             Finland      0.00
# 17             Finland      0.00
# 18             Finland      0.00
# 19             Finland      0.00
# 20             Finland      0.00
# 21             Finland      0.00
# 22             Finland      0.00
# 23             Finland      0.00
# 24             Finland      0.00
# 25             Finland      3.00
# 26              France    119.00
# ...

# %%
country_stats.query('quantity > 184264.77005012965').head()
# Out:
#             country  quantity
# 3228  United States  367987.0
# 3229  United States  384439.0
# 3230  United States  370625.0
# 3231  United States  310909.0
# 3232  United States  335418.0

# %%
average_level = data['quantity'].mean()

# %%
above_average = country_stats.query('quantity > {}'.format(average_level))

# %%
above_average
# Out:
#                     country   quantity
# 3228          United States   367987.0
# 3229          United States   384439.0
# 3230          United States   370625.0
# 3231          United States   310909.0
# 3232          United States   335418.0
# 3233          United States   230589.0
# 3234          United States   226570.0
# 3235          United States   221771.0
# 3237          United States   314655.0
# 3238          United States   243916.0
# 3244          United States   226319.0
# 3245          United States   292568.0
# 3246          United States   230254.0
# 3247          United States   247909.0
# 3539          United States   448216.0
# 3540          United States   458711.0
# 3541          United States   433505.0
# 3542          United States   382566.0
# 3543          United States   406606.0
# 3544          United States   296903.0
# 3545          United States   298551.0
# 3546          United States   294620.0
# 3547          United States   242580.0
# ...

# %%
above_average['country'].value_counts()
# Out:
# United States                3318
# China                        2086
# Russian Federation           1820
# Japan                        1164
# India                        1025
# Germany                       989
# Canada                        962
# United Kingdom                676
# Ukraine                       658
# Indonesia                     616
# Italy                         589
# Brazil                        564
# Iran (Islamic Rep. of)        563
# Australia                     531
# Mexico                        517
# France                        510
# Saudi Arabia                  449
# Kazakhstan                    416
# Korea, Republic of            415
# Venezuela (Bolivar. Rep.)     409
# Poland                        405
# Nigeria                       368
# Netherlands                   364
# Argentina                     359
# Algeria                       351
# United Arab Emirates          338
# Romania                       321
# ...

# %%
data[ data.quantity > average_level ].head()
# Out:
#             country  year  quantity  category
# 3228  United States  2014  367987.0         2
# 3229  United States  2013  384439.0         2
# 3230  United States  2012  370625.0         2
# 3231  United States  2011  310909.0         2
# 3232  United States  2010  335418.0         2

# %%
data[ data['quantity'] > average_level ].head()
# Out:
#             country  year  quantity  category
# 3228  United States  2014  367987.0         2
# 3229  United States  2013  384439.0         2
# 3230  United States  2012  370625.0         2
# 3231  United States  2011  310909.0         2
# 3232  United States  2010  335418.0         2

# %%
data[ data['country'].str.contains('rus', case=False) ]['country'].unique()
# Out:
# array(['Brunei Darussalam', 'Russian Federation', 'Belarus', 'Cyprus'],
#       dtype=object)

# %%
len(data[ data['country'].str.contains('state', case=False) ]['country'].unique())
# Out:
# 6

# %%
filtered_countries = data[ (data['country']=='Russian Federation') | (data['country']=='Belarus') ]

filtered_countries.head()
# Out:
#                  country  year  quantity  category
# 6940  Russian Federation  2014   12714.0         3
# 6941  Russian Federation  2013   11285.0         3
# 6942  Russian Federation  2012   11302.0         3
# 6943  Russian Federation  2011    7611.0         3
# 6944  Russian Federation  2010    9263.0         3

# %%
data.loc[100:105, ['country', 'quantity']]
# Out:
#          country  quantity
# 100  Netherlands     276.0
# 101  Netherlands     302.0
# 102  Netherlands     271.0
# 103  Netherlands     244.0
# 104  Netherlands     251.0
# 105  Netherlands     364.0

# %%
data.loc[data['year'] == 2014, 'quantity']
# Out:
# 2               0.00
# 26            119.00
# 45              2.00
# 57              4.00
# 86            390.00
# 106             0.00
# 114             4.00
# 120             0.00
# 127            54.00
# 128          2484.00
# 166             0.00
# 172             8.00
# 177            36.00
# 187          5240.00
# 194           302.00
# 203            58.00
# 221            12.00
# 262            89.00
# 286           221.00
# 311             0.00
# 323          1538.00
# 331           199.00
# 354           103.00
# 358            46.00
# 373            39.00
# 381           454.00
# 406           665.00
# 426           318.00
# 433           317.00
# 441            79.00
#              ...
# 1189063       116.30
# 1189068       256.00
# 1189083       152.10
# 1189097      7676.00
# 1189117     12111.00
# 1189142       219.10
# 1189144         1.00
# 1189151        15.70
# 1189162      6201.00
# 1189176        96.00
# 1189194         7.09
# 1189196         6.00
# ...

# %%
filtered_countries['year'].value_counts()
# Out:
# 2010    1215
# 2008    1203
# 2009    1192
# 2011    1191
# 2012    1183
# 2014    1171
# 2013    1163
# 2007    1150
# 2006    1146
# 2005    1040
# 2003     997
# 2004     993
# 2000     984
# 2002     982
# 2001     972
# 1999     942
# 1998     934
# 1997     914
# 1995     898
# 1996     896
# 1993     860
# 1994     857
# 1992     814
# Name: year, dtype: int64

# %%
data.sort_values(by='quantity').head()
# Out:
#               country  year  quantity  category
# 832375  United States  2000 -864348.0        42
# 832373  United States  2002 -562414.0        42
# 832362  United States  2013 -551490.0        42
# 832380  United States  1995 -493380.0        42
# 832322        Ukraine  2010 -477263.0        42

# %%
data.sort_values(by='quantity', ascending=False)
# Out:
#                    country  year      quantity  category
# 492581       United States  2014  6.680329e+09        31
# 492267       United States  2014  6.680329e+09        31
# 492047               China  2014  5.462672e+09        31
# 492345               China  2014  5.462672e+09        31
# 122392       USSR (former)  1990  3.257000e+09        12
# 121415       USSR (former)  1990  3.100000e+09        12
# 492220  Russian Federation  2014  2.727915e+09        31
# 492530  Russian Federation  2014  2.727915e+09        31
# 122345  Russian Federation  1997  2.482908e+09        12
# 121392  Russian Federation  1997  2.358085e+09        12
# 492589       USSR (former)  1990  2.230000e+09        31
# 836155       USSR (former)  1990  2.127815e+09        42
# 491533       USSR (former)  1990  2.100000e+09        31
# 835931  Russian Federation  1993  1.879251e+09        42
# 835924  Russian Federation  2005  1.865984e+09        42
# ...

# %%
data.sort_values(by=['country', 'year'], ascending=[True, True]).head()
# Out:
#            country  year  quantity  category
# 9996   Afghanistan  1990       3.0         4
# 12134  Afghanistan  1990       3.0         4
# 14904  Afghanistan  1990       3.0         4
# 17054  Afghanistan  1990       3.0         4
# 21688  Afghanistan  1990       0.0         4

# %%
data.sort_values(by=['country', 'year', 'quantity'], ascending=[True, True, False], inplace=True)

# %%
data2[data2['Product']=='_8'].sort_values(by=['Cost'], ascending=[True])
# Out:
#       Year  Month    ID Product  Amount   Price    Total    Cost
# 22  2012.0    6.0  t023      _8    10.0  3760.0  37600.0   200.0
# 37  2012.0    9.0  t038      _8     1.0  3760.0   3760.0   700.0
# 26  2012.0    6.0  t027      _8     3.0  3760.0  11280.0   800.0
# 41  2012.0   10.0  t042      _8     3.0  3760.0  11280.0   800.0
# 58  2012.0   12.0  t059      _8     3.0  3760.0  11280.0   800.0
# 8   2012.0    4.0  t009      _8     3.0  3760.0  11280.0  1000.0
# 12  2012.0    4.0  t013      _8     3.0  3760.0  11280.0  1200.0
# 54  2012.0   12.0  t055      _8     2.0  3760.0   7520.0  2400.0

# %% [markdown]
# ДЗ

# %%
data[ data['country'].str.contains('lat', case=False) ]['country'].unique()
# Out:
# array(['Latvia'], dtype=object)

# %%
data[ data['country'].str.contains('lit', case=False) ]['country'].unique()
# Out:
# array(['Lithuania'], dtype=object)

# %%
data[ data['country'].str.contains('est', case=False) ]['country'].unique()
# Out:
# array(['Estonia', 'State of Palestine', 'Timor-Leste'], dtype=object)

# %%
filtered_countries2 = data[ (data['country']=='Latvia') | (data['country']=='Lithuania') | (data['country']=='Estonia') ]

# %%
filtered_countries2
# Out:
#            country  year  quantity  category
# 553886     Estonia  1992   69255.0        32
# 555162     Estonia  1992   69255.0        32
# 557297     Estonia  1992   69255.0        32
# 536047     Estonia  1992   68447.0        32
# 561954     Estonia  1992   68447.0        32
# 552667     Estonia  1992   58918.0        32
# 537123     Estonia  1992   42441.0        32
# 547033     Estonia  1992   34130.0        32
# 818266     Estonia  1992   33381.0        42
# 833257     Estonia  1992   33381.0        42
# 538157     Estonia  1992   26006.0        32
# 545029     Estonia  1992   24788.0        32
# 548165     Estonia  1992   24788.0        32
# 550810     Estonia  1992   24788.0        32
# 860846     Estonia  1992   20525.0        47
# 860908     Estonia  1992   20107.0        47
# 836968     Estonia  1992   19295.0        42
# 841118     Estonia  1992   19295.0        42
# 860761     Estonia  1992   18849.0        47
# 860979     Estonia  1992   17938.0        47
# ...

# %%
filtered_countries2 = filtered_countries2[(filtered_countries2['year'] >= 2005) & (filtered_countries2['year'] <= 2010)]

# %%
filtered_countries2 = filtered_countries2[(filtered_countries2['quantity'] >= 0)]

# %%
filtered_countries2
# Out:
#            country  year   quantity  category
# 198009     Estonia  2005  2494000.0        18
# 198138     Estonia  2005  2494000.0        18
# 818253     Estonia  2005    37201.0        42
# 833244     Estonia  2005    37201.0        42
# 553873     Estonia  2005    26777.0        32
# 555149     Estonia  2005    26777.0        32
# 557284     Estonia  2005    26777.0        32
# 536034     Estonia  2005    23171.0        32
# 561941     Estonia  2005    23171.0        32
# 552654     Estonia  2005    22919.0        32
# 547020     Estonia  2005    20421.0        32
# 836955     Estonia  2005    19213.0        42
# 841105     Estonia  2005    19213.0        42
# 812227     Estonia  2005    17700.0        42
# 543057     Estonia  2005    15801.0        32
# 860833     Estonia  2005    14804.0        47
# 860748     Estonia  2005    14591.0        47
# 860895     Estonia  2005    14433.0        47
# 538144     Estonia  2005    13889.0        32
# ...

# %%
cat = [4, 12, 21]

# %%
filtered_countries2=filtered_countries2[(filtered_countries2['category'].isin(cat) )]

# %%
sum(filtered_countries2['quantity'])
# Out:
# 240580.0
